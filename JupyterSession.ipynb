# %%
import numpy as np
import pandas as pd
import os.path as path


def get_some_random_number_multi_dimension(*argv, **kwargs):
    rand = np.random.rand(*argv, **kwargs)
    return rand



def get_some_random_numbers(how_many):
    random_num = np.random.rand(how_many)
    return random_num


def create_panda_series_with_index(nums, index):
    rn = get_some_random_numbers(nums)
    sr = pd.Series(data=rn, name="Ten Random Numbers", index=index)
    return sr


def show_pandas_series_metadata():
    sr = create_panda_series_with_index(nums=10, index="a b c d e f g h i j".split())
    print(sr)
    return sr


def get_csv_from_website(url, number_of_rows_to_get: int):
    """

    :param number_of_rows_to_get: how many rows to return from the website
    :param url: https link
    :return: dataframe from data that lives in teh https link

    Note: in order from reading of data from url to work, you have to
        install ssl script: "Install Certificates.command"
        under the Python installed root directory.
        The Python install process does not seem to run this as a default
    """
    data_file = "./artwork_data.csv"

    if not path.exists(data_file):
        return pd.read_csv(url, nrows=number_of_rows_to_get)
    else:
        return pd.read_csv(data_file, nrows=number_of_rows_to_get)


def get_tate_data(
        url='https://raw.githubusercontent.com/tategallery/collection/master/artwork_data.csv') -> pd.DataFrame:
    """
    Assumes the tate like is in the default param to this function

    :return: data from the tate dataset as a Pandas.DataFrame
    """
    columns_of_interest = ['id', 'artist', 'title', 'medium',
                           'year', 'acquisitionYear', 'height', 'width', 'units']

    local_data_file = "./artwork_data.csv"

    if not path.exists(local_data_file):
        source_location = local_data_file
    else:
        source_location = url

    dframe = pd.read_csv(source_location,
                         usecols=columns_of_interest,
                         index_col='id')
    return dframe


def save_data_to_pickle(dframe: pd.DataFrame, save_file: str = "save_data.pickle"):
    dframe.to_pickle("save_file")


def retrieve_from_pickle(pickle_file:str) -> pd.DataFrame:
    df = pd.read_pickle(pickle_file)
    return df


def get_distinct_list_of_artists(dframe: pd.DataFrame):
    """
        LEARNING Point: DataFrame has a unique() function return distinct elements in a column

    :param dframe: data from which to get the artist column
    :return:
    """
    distinct_list = sorted(dframe["artist"].unique())  # LEARNING POINT: "unique" function in dataframe
    distinct_list = [(artist[0], artist) for artist in distinct_list]
    return len(distinct_list), distinct_list


def get_filtering_particular_artist(dframe: pd.DataFrame,
                                    artist_name: str = 'Bacon, Francis') -> int:
    """
        LEARNING POINT: Filtering for a particular artist
    :param dframe:
    :param artist_name:
    :return:
    """

    # LEARNING: returns a series of True or False for each row, indicating
    # which row has artist == artist_name
    truth_table = (dframe['artist'] == artist_name)  # LEARNING: df["column"]== FilterValue

    # LEARNING: series has a value_counts() function
    # counts unique values in a series and return the number of times it appears in teh
    # series, like count(*) group by the column
    truth_table_count_true_or_false = truth_table.value_counts()  # LEARNING: value_counts()

    return truth_table_count_true_or_false[True]


def get_count_of_work_by_each_artist(dframe: pd.DataFrame) -> pd.DataFrame:
    """
        GET count of work for each artist, using the value_counts() for the entire column
        This is like ding a group by in SQL for that column and doing a select count(*)
    :param dframe: 
    :return: 
    """
    df = pd.DataFrame(data=dframe['artist'].value_counts())
    df.rename(columns={"artist": "WorkCount"}, inplace=True)
    print("columns: ", df.columns)
    return df

# %%
# get the data
df_local = get_tate_data()
print(df_local.columns)

# save the data as pickle (binary)
save_data_to_pickle(df_local)

# get unique artists
artist_count, distinct_artists = get_distinct_list_of_artists(df_local)

[print(artist) for artist in distinct_artists]
print("distinct artist count:", artist_count)

# Filter for one artist
artist = 'Bacon, Francis'
count = get_filtering_particular_artist(df_local, artist)
print("# of works by", artist, "is:", count)

# Count # of work by each artist
count_summary_df = get_count_of_work_by_each_artist(df_local)

count_summary_df.rename = count_summary_df.rename(columns={"artist": "Artifact_Count"})
print("\ncolumns:", count_summary_df.columns)

print(count_summary_df)
# [print(count_item["index"]) for count_item in count_summary_df]

# plotting does not seem to work
count_summary_df.plot()
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Index(['artist', 'title', 'medium', 'year', 'acquisitionYear', 'width',
#        'height', 'units'],
#       dtype='object')
# ('?', '?British School')
# ('A', 'Abakanowicz, Magdalena')
# ('A', 'Abbey, Edwin Austin')
# ('A', 'Abbott, Berenice')
# ('A', 'Abbott, Lemuel Francis')
# ('A', 'Abrahams, Ivor')
# ('A', 'Absalon')
# ('A', 'Abts, Tomma')
# ('A', 'Acconci, Vito')
# ('A', 'Ackling, Roger')
# ('A', 'Ackroyd, Norman')
# ('A', 'Adam, Robert')
# ('A', 'Adams, Harry William')
# ('A', 'Adams, Norman')
# ('A', 'Adams, Robert')
# ('A', 'Adeney, Bernard')
# ('A', 'Adler, Jankel')
# ('A', 'Adshead, Mary')
# ('A', 'Adzak, Roy')
# ('A', 'Afro')
# ('A', 'Agar, Eileen')
# ('A', 'Agasse, Jacques Laurent')
# ('A', 'Ahtila, Eija-Liisa')
# ('A', 'Ai, Weiwei')
# ('A', 'Aitchison, Craigie')
# ('A', 'Ajmone, Giuseppe')
# ('A', 'Aksel, Erdag')
# ('A', 'Al-Ani, Jananne')
# ('A', 'Albers, Josef')
# ('A', 'Albright, Ivan')
# ('A', 'Aldridge, John')
# ('A', 'Alechinsky, Pierre')
# ('A', 'Alexander, Edwin')
# ('A', 'Alexander, William')
# ('A', 'Alimpiev, Victor')
# ('A', 'Alken Family')
# ('A', 'Alken, Henry Thomas')
# ('A', 'Alken, Samuel, Senior')
# ('A', 'Allan, David')
# ('A', 'Allan, Julian Phelps')
# ('A', 'Allan, Sir William')
# ('A', 'Allen, George Warner')
# ('A', 'Allen, Joseph William')
# ('A', 'Allen, Phillip')
# ('A', 'Allen, Richard')
# ('A', 'Alley, Anthea')
# ('A', 'Allington, Edward')
# ('A', 'Allinson, Adrian')
# ('A', 'Allom, Thomas')
# ('A', 'Allora, Jennifer')
# ('A', 'Alma-Tadema, Sir Lawrence')
# ('A', 'Almeida, Helena')
# ('A', 'Almond, Darren')
# ('A', 'Althamer, Pawel')
# ('A', 'Altoon, John')
# ('A', 'Alÿs, Francis')
# ('A', 'Amiconi, Giacomo')
# ('A', 'Amiet, Cuno')
# ('A', 'Amorales, Carlos')
# ('A', 'Amuchastegui, Axel')
# ('A', 'Anderson, Hurvin')
# ('A', 'Anderton, Henry')
# ('A', 'Andrade Tudela, Armando')
# ('A', 'Andrade, Jonathas de')
# ('A', 'Andre, Carl')
# ('A', 'Andreenko, Michel')
# ('A', 'Andrews, Michael')
# ('A', 'Angellis, Peter')
# ('A', 'Annesley, David')
# ('A', 'Anquetin, Louis')
# ('A', 'Anrep, Boris')
# ('A', 'Ansarinia, Nazgol')
# ('A', 'Ansdell, Richard')
# ('A', 'Anselmo, Giovanni')
# ('A', 'Anuszkiewicz, Richard')
# ('A', 'Appel, Karel')
# ('A', 'Appelbee, Leonard')
# ('A', 'Appleyard, Fred')
# ('A', 'Apóstol, Alexander')
# ('A', 'Araeen, Rasheed')
# ('A', 'Arakawa, Shusaku')
# ('A', 'Araki, Nobuyoshi')
# ('A', 'Araujo, Juan')
# ('A', 'Arbus, Diane')
# ('A', 'Archipenko, Alexander')
# ('A', 'Ardizzone, Edward')
# ('A', 'Ardon, Mordecai')
# ('A', 'Arikha, Avigdor')
# ('A', 'Arman')
# ('A', 'Armfield, Maxwell Ashby')
# ('A', 'Armitage, Edward')
# ('A', 'Armitage, Kenneth')
# ('A', 'Armstead, Henry Hugh')
# ('A', 'Armstrong, John')
# ('A', 'Arnald, George')
# ('A', 'Arnatt, Keith')
# ('A', 'Arp, Jean')
# ('A', 'Art & Language (Harold Hurrell)')
# ('A', 'Art & Language (Ian Burn)')
# ('A', 'Art & Language (Ian Burn, 1939-1993; Mel Ramsden, born 1944)')
# ('A', 'Art & Language (Michael Baldwin)')
# ('A', 'Art & Language (Michael Baldwin, born 1945; Mel Ramsden, born 1944)')
# ('A', 'Art & Language (Terry Atkinson, born 1939; David Bainbridge, born 1941; Michael Baldwin, born 1945; Harold Hurrell, born')
# ('A', 'Art & Language (Terry Atkinson, born 1939; Michael Baldwin, born 1945)')
# ('A', 'Artaud, William')
# ('A', 'Artschwager, Richard')
# ('A', 'Askew, Victor')
# ('A', 'Ataman, Kutlug')
# ('A', 'Atay, Fikret')
# ('A', 'Atkins, Ed')
# ('A', 'Atkins, Samuel')
# ('A', 'Atkinson, Conrad')
# ('A', 'Atkinson, John Augustus')
# ('A', 'Atkinson, Lawrence')
# ('A', 'Atkinson, Terry')
# ('A', 'Atlan, Jean-Michel')
# ('A', 'Atlas Group')
# ('A', 'Atlas, Charles')
# ('A', 'Attia, Kader')
# ('A', 'Atwood, Clare')
# ('A', 'Auerbach, Arnold')
# ('A', 'Auerbach, Frank')
# ('A', 'Aumonier, James')
# ('A', 'Austen, David')
# ('A', 'Austin, Robert')
# ('A', 'Avedon, Richard')
# ('A', 'Avery, Charles')
# ('A', 'Avery, Milton')
# ('A', 'Aylesford, Heneage Finch, Fifth Earl of')
# ('A', 'Aylesford, Heneage Finch, Fourth Earl of')
# ('A', 'Ayot, Pierre')
# ('A', 'Ayres, OBE Gillian')
# ('A', 'Ayrton, Michael')
# ('B', 'Baalbaki, Ayman')
# ('B', 'Bacon, Francis')
# ('B', 'Bacon, John Henry F.')
# ('B', 'Bacon, Sir Nathaniel')
# ('B', 'Baer, Jo')
# ('B', 'Baertling, Olle')
# ('B', 'Baily, Edward Hodges')
# ('B', 'Baj, Enrico')
# ('B', 'Bakhshi Moakhar, Mahmoud')
# ('B', 'Baldessari, John')
# ('B', 'Balka, Miroslaw')
# ('B', 'Balla, Giacomo')
# ('B', 'Ballen, Roger')
# ('B', 'Baltz, Lewis')
# ('B', 'Banc, Jef')
# ('B', 'Banner, Fiona')
# ('B', 'Banting, John')
# ('B', 'Baran, Stefan')
# ('B', 'Barclay, Claire')
# ('B', 'Barenger, James')
# ('B', 'Barham, Anna')
# ('B', 'Barker, Clive')
# ('B', 'Barker, Margaret')
# ('B', 'Barker, Thomas, of Bath')
# ('B', 'Barlach, Ernst')
# ('B', 'Barlow, Francis')
# ('B', 'Barlow, Phyllida')
# ('B', 'Barnard, Rev. William Henry')
# ('B', 'Barney, Matthew')
# ('B', 'Barni, Roberto')
# ('B', 'Barns-Graham, Wilhelmina')
# ('B', 'Barrada, Yto')
# ('B', 'Barret, George, Junior')
# ('B', 'Barret, George, Senior')
# ('B', 'Barriball, Anna')
# ('B', 'Barron, Hugh')
# ('B', 'Barrow, Joseph Charles')
# ('B', 'Barry, James')
# ('B', 'Bartana, Yael')
# ('B', 'Barth, Uta')
# ('B', 'Bartlett, Jennifer')
# ('B', 'Bartolozzi, Francesco')
# ('B', 'Basbaum, Ricardo')
# ('B', 'Baselitz, Georg')
# ('B', 'Baskin, Leonard')
# ('B', 'Batchelor, David')
# ('B', 'Bateman, James')
# ('B', 'Bates, Harry')
# ('B', 'Bates, Maxwell')
# ('B', 'Batterham, Richard')
# ('B', 'Bauchant, André')
# ('B', 'Bauer, Marius')
# ('B', 'Baumeister, Willi')
# ('B', 'Baumgarten, Lothar')
# ('B', 'Bawden, Edward')
# ('B', 'Bawden, Richard')
# ('B', 'Baxter, Glen')
# ('B', 'Baxter, Iain')
# ('B', 'Baxter, Thomas Tennant')
# ('B', 'Bayer, Herbert')
# ('B', 'Bayes, Gilbert')
# ('B', 'Bayes, Walter')
# ('B', 'Baynard, Ed')
# ('B', 'Baziotes, William')
# ('B', 'Beach, Thomas')
# ('B', 'Beale, Mary')
# ('B', 'Beament, Tib')
# ('B', 'Beard, John')
# ('B', 'Beardsley, Aubrey')
# ('B', 'Beare, George')
# ('B', 'Beattie, Basil')
# ('B', 'Beaumont, Sir George Howland, Bt')
# ('B', 'Beban, Breda')
# ('B', 'Becher, Prof. Bernd')
# ('B', 'Becker, Ferdinand')
# ('B', 'Becker, Harald')
# ('B', 'Beckley, Bill')
# ('B', 'Beckmann, Max')
# ('B', 'Beechey, Sir William')
# ('B', 'Beer, Richard')
# ('B', 'Beerbohm, Sir Max')
# ('B', 'Beeton, Alan')
# ('B', 'Beggs, Guy')
# ('B', 'Behnes, William')
# ('B', 'Belcher, George')
# ('B', 'Bell, Graham')
# ('B', 'Bell, John Zephaniah')
# ('B', 'Bell, Larry')
# ('B', 'Bell, Laura Anning')
# ('B', 'Bell, Robert Anning')
# ('B', 'Bell, Trevor')
# ('B', 'Bell, Vanessa')
# ('B', 'Bellany, John')
# ('B', 'Bellegarde, Claude')
# ('B', 'Bellingham-Smith, Elinor')
# ('B', 'Bellmer, Hans')
# ('B', 'Belloguet, A.')
# ('B', 'Benazech, Peter Paul')
# ('B', 'Benglis, Lynda')
# ('B', 'Benjamin, Anthony')
# ('B', 'Bennett, William')
# ('B', 'Benois, Alexander')
# ('B', 'Benois, Nadia')
# ('B', 'Benrath, Frédéric')
# ('B', 'Benson, Abraham Harris')
# ('B', 'Berber, Mersad')
# ('B', 'Berg, Adrian')
# ('B', 'Berkeley, Rev C J R')
# ('B', 'Berman, Eugène')
# ('B', 'Bernik, Janez')
# ('B', 'Berry, John, CBE')
# ('B', 'Berthot, Jake')
# ('B', 'Bettes, John')
# ('B', 'Beuys, Joseph')
# ('B', 'Bevan, Robert')
# ('B', 'Bevan, Tony')
# ('B', 'Bhimji, Zarina')
# ('B', 'Bickerton, Ashley')
# ('B', 'Bicât, André')
# ('B', 'Biederman, Charles')
# ('B', 'Biermann, Aenne')
# ('B', 'Bigge, John')
# ('B', 'Bill, Simon')
# ('B', 'Billingham, Richard')
# ('B', 'Binning, Bertram')
# ('B', 'Bionda, Mario')
# ('B', 'Birch, Samuel John Lamorna')
# ('B', 'Bird, Edward')
# ('B', 'Bird, John')
# ('B', 'Birdhead (Ji Weiyu, born 1980; Song Tao, born 1979)')
# ('B', 'Bishop, Henry')
# ('B', 'Bissier, Julius')
# ('B', 'Bissill, George')
# ('B', 'Bissière, Roger')
# ('B', 'Bjørlo, Per Inge')
# ('B', 'Black Audio Film Collective (John Akomfrah; Reece Auguis; Edward George; Lina Gopaul; Avril Johnson; David Lawson; Trevo')
# ('B', 'Black, Karla')
# ('B', 'Black, Sheila')
# ('B', 'Blackadder, Elizabeth')
# ('B', 'Blacker, Kate')
# ('B', 'Blais, Jean-Charles')
# ('B', 'Blake, Benjamin')
# ('B', 'Blake, John')
# ('B', 'Blake, Peter')
# ('B', 'Blake, Robert')
# ('B', 'Blake, William')
# ('B', 'Blamey, Norman')
# ('B', 'Blanche, Jacques-Emile')
# ('B', 'Bland, Beatrice')
# ('B', 'Blaymires, Charles Henry')
# ('B', 'Bleckner, Ross')
# ('B', 'Blees Luxemburg, Rut')
# ('B', 'Bliss, Douglas Percy')
# ('B', 'Bloch, Martin')
# ('B', 'Blom, Ansuya')
# ('B', 'Blore, Edward')
# ('B', 'Blow, Sandra')
# ('B', 'Bo, Hou')
# ('B', 'Boccioni, Umberto')
# ('B', 'Bochner, Mel')
# ('B', 'Bock, Théophile de')
# ('B', 'Boden, Neville')
# ('B', 'Boehm, Sir Joseph Edgar')
# ('B', 'Boetti, Alighiero')
# ('B', 'Bohm, Dorothy')
# ('B', 'Boisvert, Gilles')
# ('B', 'Boitard, Louis Philippe')
# ('B', 'Boltanski, Christian')
# ('B', 'Bolus, Michael')
# ('B', 'Bomberg, David')
# ('B', 'Bond, Henry')
# ('B', 'Bone, Sir Muirhead')
# ('B', 'Bone, Stephen')
# ('B', 'Bonechi, Lorenzo')
# ('B', 'Bonington, Richard Parkes')
# ('B', 'Bonnard, Pierre')
# ('B', 'Bontecou, Lee')
# ('B', 'Booth, L')
# ('B', 'Borland, Christine')
# ('B', 'Bornfriend, Jacob')
# ('B', 'Borofsky, Jonathan')
# ('B', 'Borseller, Peter')
# ('B', 'Boshier, Derek')
# ('B', 'Bosman, Richard')
# ('B', 'Boswell, James')
# ('B', 'Boty, Pauline')
# ('B', 'Bough, Samuel')
# ('B', 'Boughton, George Henry')
# ('B', 'Boumans, Bart')
# ('B', 'Bourdelle, Antoine')
# ('B', 'Bourgeois, Louise')
# ('B', 'Bourne, James')
# ('B', 'Bouvier de Cachard, Comte Régis Guy de')
# ('B', 'Bowen, Denis')
# ('B', 'Bower, Edward')
# ('B', 'Bowey, Olwyn')
# ('B', 'Bowler, Henry Alexander')
# ('B', 'Bowling, Frank')
# ('B', 'Box, E.')
# ('B', 'Boxall, Sir William')
# ('B', 'Boxer, Stanley')
# ('B', 'Boyce, George Price')
# ('B', 'Boyce, Martin')
# ('B', 'Boyce, Sonia')
# ('B', 'Boyd Harte, Glynn')
# ('B', 'Boyd and Evans, Fionnuala and Leslie')
# ('B', 'Boyd, Arthur')
# ('B', 'Boyle, Mark')
# ('B', 'Boyne, John')
# ('B', 'Boys, Thomas Shotter')
# ('B', 'Brabazon, Hercules Brabazon')
# ('B', 'Braden, Norah')
# ('B', 'Bradford, Mark')
# ('B', 'Bradley, Martin')
# ('B', 'Bramley, Frank')
# ('B', 'Brammer, Leonard')
# ('B', 'Brancusi, Constantin')
# ('B', 'Brandard, Robert')
# ('B', 'Brandenburg, Ulla von')
# ('B', 'Brandt, Bill')
# ('B', 'Brangwyn, Sir Frank')
# ('B', 'Branson, Clive')
# ('B', 'Branwhite, Nathan')
# ('B', 'Braque, Georges')
# ('B', 'Brassai')
# ('B', 'Bratby, John')
# ('B', 'Bravo, Manuel Álvarez')
# ('B', 'Breakwell, Ian')
# ('B', 'Bree, Rev. William')
# ('B', 'Breeze, Claude')
# ('B', 'Breton, André')
# ('B', 'Brett, Bernard')
# ('B', 'Brett, John')
# ('B', 'Brett, The Hon. Dorothy')
# ('B', 'Bridell, Frederick Lee')
# ('B', 'Bridgewater, Alan')
# ('B', 'Briggs, Ernest')
# ('B', 'Briggs, Henry Perronet')
# ('B', 'Bright, Henry')
# ('B', 'Brill, Frederick')
# ('B', 'Brill, Reginald')
# ('B', 'Brisley, Stuart')
# ('B', 'British (?) School')
# ('B', 'British (?) School 19th century')
# ('B', 'British School 16th century')
# ('B', 'British School 17th century')
# ('B', 'British School 17th or 18th century')
# ('B', 'British School 18th century')
# ('B', 'British School 19th century')
# ('B', 'British School 20th century')
# ('B', 'Brock, Sir Thomas')
# ('B', 'Brockhurst, Gerald')
# ('B', 'Brodzky, Horace')
# ('B', 'Bronstein, Pablo')
# ('B', 'Broodthaers, Marcel')
# ('B', 'Brook, Peter')
# ('B', 'Brooke, William Henry')
# ('B', 'Brooker, William')
# ('B', 'Brooking, Charles')
# ('B', 'Brooks, James')
# ('B', 'Broomberg, Adam')
# ('B', 'Brough, Robert')
# ('B', 'Brough, Romey')
# ('B', 'Brouwn, Stanley')
# ('B', 'Brown, Cecily')
# ('B', 'Brown, Don')
# ('B', 'Brown, Ford Madox')
# ('B', 'Brown, Frederick')
# ('B', 'Brown, Kellock')
# ('B', 'Brown, Mortimer')
# ('B', 'Brown, Ralph')
# ('B', 'Brown, Sir Arnesby')
# ('B', 'Browne, Hablot Knight')
# ('B', 'Browne, Henriette')
# ('B', 'Bruguera, Tania')
# ('B', 'Brundrit, Reginald')
# ('B', 'Brunias, Agostino')
# ('B', 'Brunsdon, John')
# ('B', 'Brus, Günter')
# ('B', 'Bruscky, Paulo')
# ('B', 'Bruton, Jo')
# ('B', 'Bryce, Fernando')
# ('B', 'Brüning, Peter')
# ('B', 'Buchanan, Roderick')
# ('B', 'Buchheister, Carl')
# ('B', 'Buchler, Pavel')
# ('B', 'Buck, Adam')
# ('B', 'Buckingham, Matthew')
# ('B', 'Buckley, Stephen')
# ('B', 'Buffet, Bernard')
# ('B', 'Buhler, Robert')
# ('B', 'Bulloch, Angela')
# ('B', 'Bunbury, Charles')
# ('B', 'Bunbury, Henry William')
# ('B', 'Bundy, Edgar')
# ('B', 'Burchfield, Charles')
# ('B', 'Burden, Chris')
# ('B', 'Buren, Daniel')
# ('B', 'Burgin, Victor')
# ('B', 'Burkert, Robert')
# ('B', 'Burn, Rodney J.')
# ('B', 'Burne-Jones, Sir Edward Coley, Bt')
# ('B', 'Burnet, James')
# ('B', 'Burnet, John')
# ('B', 'Burney, Edward Francis')
# ('B', 'Burra, Edward')
# ('B', 'Burri, Alberto')
# ('B', 'Burt (née Dallas), Angela')
# ('B', 'Burt, Laurence')
# ('B', 'Burton, Scott')
# ('B', 'Burton, William Shakespeare')
# ('B', 'Bury, Pol')
# ('B', 'Bush, Jack')
# ('B', 'Bussy, Simon')
# ('B', 'Bustamante, Jean-Marc')
# ('B', 'Butler, Elizabeth')
# ('B', 'Butler, Mildred Anne')
# ('B', 'Butler, Reg')
# ('B', 'Butler, Samuel')
# ('B', 'Butts, John')
# ('B', 'Buvelot, Louis')
# ('B', 'Byrne, Gerard')
# ('B', 'Béraud, Jean')
# ('C', 'Cabrita Reis, Pedro')
# ('C', 'Cadere, André')
# ('C', 'Cage, John')
# ('C', 'Cahn, Miriam')
# ('C', 'Cahun, Claude')
# ('C', 'Cain, Neville')
# ('C', 'Caiserman-Roth, Ghitta')
# ('C', 'Caldecott, Randolph')
# ('C', 'Calder, Alexander')
# ('C', 'Calderon, Philip Hermogenes')
# ('C', 'Callahan, Harry')
# ('C', 'Callcott, Sir Augustus Wall')
# ('C', 'Calle, Sophie')
# ('C', 'Callery, Simon')
# ('C', 'Calliyannis, Manolis')
# ('C', 'Callow, William')
# ('C', 'Calthrop, Claude')
# ('C', 'Calvert, Charles')
# ('C', 'Calvert, Edward')
# ('C', 'Camargo, Sergio de')
# ('C', 'Cameron, Katherine')
# ('C', 'Cameron, Sir David')
# ('C', 'Camnitzer, Luis')
# ('C', 'Camp, Jeffery')
# ('C', 'Campbell, Duncan')
# ('C', 'Campbell, James')
# ('C', 'Campbell, Steven')
# ('C', 'Campion, George B.')
# ('C', 'Caniaris, Vlassis')
# ('C', 'Canin, Martin')
# ('C', 'Cantor, Ellen')
# ('C', 'Cao, Fei')
# ('C', 'Capel Doray, Audrey')
# ('C', 'Carder, Malcolm')
# ('C', 'Cardew, Michel')
# ('C', 'Cardoso, José, Junior')
# ('C', 'Cardoso, Maria')
# ('C', 'Carline, George')
# ('C', 'Carline, Hilda')
# ('C', 'Carline, Nancy')
# ('C', 'Carline, Richard')
# ('C', 'Carline, Sydney')
# ('C', 'Carlisle, George Howard, Ninth Earl of')
# ('C', 'Carlo, Michael')
# ('C', 'Carnegie, Gillian')
# ('C', 'Caro, Antonio')
# ('C', 'Caro, Sir Anthony')
# ('C', 'Carr, Thomas')
# ('C', 'Carrington, Dora')
# ('C', 'Carrington, Leonora')
# ('C', 'Carrière, Eugène')
# ('C', 'Carter, B.A.R.')
# ('C', 'Carter, Hugh')
# ('C', 'Carter, Nathan')
# ('C', 'Carter, Samuel John')
# ('C', 'Carter, William')
# ('C', 'Cartier-Bresson, Henri')
# ('C', 'Carwitham, Thomas')
# ('C', 'Casas, Juan Vila')
# ('C', 'Cast, Jesse Dale')
# ('C', 'Cattermole, George')
# ('C', 'Caulfield, Patrick')
# ('C', 'Cazin, Jean-Charles')
# ('C', 'Cazin, Marie')
# ('C', 'Celic, Stojan')
# ('C', 'Celice, Pierre')
# ('C', 'Celmins, Vija')
# ('C', 'Chadwick, Helen')
# ('C', 'Chadwick, Lynn')
# ('C', 'Chagall, Marc')
# ('C', 'Chaimowicz, Marc Camille')
# ('C', 'Challenger, Michael')
# ('C', 'Chalon, Henry Bernard')
# ('C', 'Chamberlain, Christopher')
# ('C', 'Chamberlain, John')
# ('C', 'Chambers, George')
# ('C', 'Chandler, J.W.')
# ('C', 'Chandra, Avinash')
# ('C', 'Chaney, Israel')
# ('C', 'Channer, Alice')
# ('C', 'Chantrey, Sir Francis Legatt')
# ('C', 'Chaplin, Bob')
# ('C', 'Chapman, Jake')
# ('C', 'Chappell, William')
# ('C', 'Charbonneau, Monique')
# ('C', 'Charles, James')
# ('C', 'Charlton, Alan')
# ('C', 'Charlton, Evan')
# ('C', 'Charlton, George')
# ('C', 'Charnay, Armand')
# ('C', 'Charoux, Siegfried')
# ('C', 'Chase, William')
# ('C', 'Chatelain, Jean Baptiste Claude')
# ('C', 'Chaves, Raimond')
# ('C', 'Cheese, Bernard')
# ('C', 'Cheese, Chloe')
# ('C', 'Chen, Zhen')
# ('C', 'Chernysheva, Olga')
# ('C', 'Cheston, Charles')
# ('C', 'Cheston, Evelyn')
# ('C', 'Chetwynd, Spartacus')
# ('C', 'Chia, Sandro')
# ('C', 'Chighine, Alfredo')
# ('C', 'Chillida, Eduardo')
# ('C', 'Chinnery, George')
# ('C', 'Chodzko, Adam')
# ('C', 'Choucair, Saloua Raouda')
# ('C', 'Chowne, Gerard')
# ('C', 'Christie, John')
# ('C', 'Christo')
# ('C', 'Churchill, Sir Winston')
# ('C', 'Churchyard, Thomas')
# ('C', 'Chéron, Louis')
# ('C', 'Ciardi, Emma')
# ('C', 'Cinicolo, Donato')
# ('C', 'Cipriani, Giovanni Battista')
# ('C', 'City Racing (Matt Hale; Paul Noble, born 1963; John Burgess; Keith Coventry, born 1958; Peter Owen)')
# ('C', 'Ciuha, Joze')
# ('C', 'Clark, Joseph')
# ('C', 'Clark, Judy')
# ('C', 'Clark, Lygia')
# ('C', 'Clarke Hall, Lady Edna')
# ('C', 'Clarke, Brian')
# ('C', 'Clarke, Geoffrey')
# ('C', 'Clarke, Graham')
# ('C', 'Clatworthy, Robert')
# ('C', 'Clausen, Sir George')
# ('C', 'Clavé, Antoni')
# ('C', 'Claydon, Steven')
# ('C', 'Clemente, Francesco')
# ('C', 'Clemente, Jack')
# ('C', 'Clennell, Luke')
# ('C', 'Cleyn, Francis')
# ('C', 'Clint, Alfred')
# ('C', 'Clint, George')
# ('C', 'Clinton, Margery')
# ('C', 'Close, Chuck')
# ('C', 'Clough, Prunella')
# ('C', 'Cluett, Shelagh')
# ('C', 'Coates, George')
# ('C', 'Cockram, George')
# ('C', 'Cohen, Bernard')
# ('C', 'Cohen, Harold')
# ('C', 'Cohen, Lynne')
# ('C', 'Coker, Peter')
# ('C', 'Coldstream, Sir William')
# ('C', 'Coldwell, Paul')
# ('C', 'Cole, George Vicat')
# ('C', 'Cole, T')
# ('C', 'Coleman, James')
# ('C', 'Colescott, Warrington')
# ('C', 'Colla, Ettore')
# ('C', 'Collein, Edmund')
# ('C', 'Collet, John')
# ('C', 'Collier, Anne')
# ('C', 'Collier, Edward')
# ('C', 'Collier, The Hon. John')
# ('C', 'Collier, Thomas')
# ('C', 'Collings, Samuel')
# ('C', 'Collins, Cecil')
# ('C', 'Collins, Charles')
# ('C', 'Collins, Charles Allston')
# ('C', 'Collins, Elisabeth')
# ('C', 'Collins, Hannah')
# ('C', 'Collins, Phil')
# ('C', 'Collins, William')
# ('C', 'Collinson, James')
# ('C', 'Collishaw, Mat')
# ('C', 'Colman, Samuel')
# ('C', 'Colone, Adam de')
# ('C', 'Colquhoun, Ithell')
# ('C', 'Colquhoun, Robert')
# ('C', 'Colton, William Robert')
# ('C', 'Colverson, Ian')
# ('C', 'Colvin, Calum')
# ('C', 'Conder, Charles')
# ('C', 'Connard, Philip')
# ('C', 'Consagra, Pietro')
# ('C', 'Consemüller, Erich')
# ('C', 'Constable, George')
# ('C', 'Constable, John')
# ('C', 'Constable, Lionel Bicknell')
# ('C', 'Constant')
# ('C', 'Cook, Barrie')
# ('C', 'Cook, Richard')
# ('C', 'Cook, William, of Plymouth')
# ('C', 'Cooke, Edward William')
# ('C', 'Cooke, Jean')
# ('C', 'Cooke, Nigel')
# ('C', 'Cooper, Abraham')
# ('C', 'Cooper, Austin')
# ('C', 'Cooper, George')
# ('C', 'Cooper, Gerald')
# ('C', 'Cooper, Richard, Junior')
# ('C', 'Cooper, Thomas Joshua')
# ('C', 'Cooper, Thomas Sidney')
# ('C', 'Coplans, John')
# ('C', 'Copley, John Singleton')
# ('C', 'Copley, William N.')
# ('C', 'Coppola, Horacio')
# ('C', 'Corbet, Matthew Ridley')
# ('C', 'Corbould, Richard')
# ('C', 'Cordell, Magda')
# ('C', 'Cordery, Don')
# ('C', 'Corinth, Lovis')
# ('C', 'Corker, Douglas')
# ('C', 'Corneille, Guillaume')
# ('C', 'Cornell, Joseph')
# ('C', 'Cosway, Richard')
# ('C', 'Cotes, Francis')
# ('C', 'Cotman, John Joseph')
# ('C', 'Cotman, John Sell')
# ('C', 'Cottingham, Robert')
# ('C', 'Couderc, Gabriel')
# ('C', 'Coventry, Keith')
# ('C', 'Cowie, James')
# ('C', 'Cowper, Frank Cadogan')
# ('C', 'Cox, David')
# ('C', 'Cox, Stephen')
# ('C', 'Coxon, Raymond')
# ('C', 'Cozens, Alexander')
# ('C', 'Cozens, John Robert')
# ('C', 'Cradock, Marmaduke')
# ('C', 'Cragg, Tony')
# ('C', 'Craig, Frank')
# ('C', 'Craig-Martin, Michael')
# ('C', 'Cranch, John')
# ('C', 'Crane, Walter')
# ('C', 'Crawford, Susan')
# ('C', 'Crawhall, Joseph')
# ('C', 'Craxton, John')
# ('C', 'Cree, Janet')
# ('C', 'Creed, Martin')
# ('C', 'Creffield, Dennis')
# ('C', 'Creswick, Thomas')
# ('C', 'Crippa, Roberto')
# ('C', 'Crisp, Fiona')
# ('C', 'Cristall, Joshua')
# ('C', 'Critchlow, Keith')
# ('C', 'Crome, John')
# ('C', 'Crome, John Berney')
# ('C', 'Cross, Dorothy')
# ('C', 'Crotch, Dr William')
# ('C', 'Crotti, Jean')
# ('C', 'Crowe, Eyre')
# ('C', 'Crozier, William')
# ('C', 'Cruikshank, George')
# ('C', 'Crutchfield, William')
# ('C', 'Cruz-Diez, Carlos')
# ('C', 'Cruzvillegas, Abraham')
# ('C', 'Cucchi, Enzo')
# ('C', 'Cuitt, George, Junior')
# ('C', 'Cuixart, Modestos')
# ('C', 'Cullen, Martin')
# ('C', 'Cumberland, George')
# ('C', 'Cundall, Charles')
# ('C', 'Cundell, Nora L.M.')
# ('C', 'Cunha, Alexandre da')
# ('C', 'Currie, John S.')
# ('C', 'Currie, Ken')
# ('C', 'Currin, John')
# ('C', 'Curtis, Layla')
# ('C', 'Cutts, Simon')
# ('C', 'Cytter, Keren')
# ('C', 'César')
# ('C', 'Cézanne, Paul')
# ('D', "D'Arcangelo, Allan")
# ('D', 'Dacre, Lady')
# ('D', 'Dadamaino')
# ('D', 'Dadd, Frank')
# ('D', 'Dadd, Richard')
# ('D', 'Daglish, Peter')
# ('D', 'Dahl, Michael')
# ('D', 'Dall, Nicholas Thomas')
# ('D', 'Dalou, Jules')
# ('D', 'Dalton, Richard')
# ('D', 'Dalwood, Dexter')
# ('D', 'Dalwood, Hubert')
# ('D', 'Dalziel, Edward')
# ('D', 'Dalziel, Edward Gurden')
# ('D', 'Dalziel, Thomas')
# ('D', 'Dalí, Salvador')
# ('D', 'Damer, Anne Seymour')
# ('D', 'Danby, Francis')
# ('D', 'Dance, George')
# ('D', 'Dance-Holland, Sir Nathaniel')
# ('D', 'Daniell, Thomas')
# ('D', 'Daniell, William')
# ('D', 'Daniels, Harvey')
# ('D', 'Daniëls, René')
# ('D', 'Dant, Adam')
# ('D', 'Darboven, Hanne')
# ('D', 'Davenport, Ian')
# ('D', 'Davey, Grenville')
# ('D', 'David, Allen')
# ('D', 'David, Enrico')
# ('D', 'Davie, Alan')
# ('D', 'Davies, John')
# ('D', 'Davies, Peter')
# ('D', 'Davis, Edward Thompson, of Worcester')
# ('D', 'Davis, Gene')
# ('D', 'Davis, Henry William Banks')
# ('D', 'Davis, John Scarlett')
# ('D', 'Davis, Lady')
# ('D', 'Davis, Ron')
# ('D', 'Davis, Stuart')
# ('D', 'Davis, William')
# ('D', 'Davison, Francis')
# ('D', 'Dawe, George')
# ('D', 'Daws, Lawrence')
# ('D', 'Dayes, Edward')
# ('D', 'De Belleroche, Count Albert')
# ('D', 'De Chirico, Giorgio')
# ('D', 'De Francia, Peter')
# ('D', 'De Glehn, Wilfred Gabriel')
# ('D', 'De Grey, Sir Roger')
# ('D', 'De Karlowska, Stanislawa')
# ('D', 'De Loutherbourg, Philip James')
# ('D', 'De Maistre, Roy')
# ('D', 'De Monchaux, Cathy')
# ('D', 'De Rivera, José')
# ('D', 'De Wint, Peter')
# ('D', 'DeLap, Tony')
# ('D', 'Deacon, James')
# ('D', 'Deacon, Richard')
# ('D', 'Dean, Catherine')
# ('D', 'Dean, Tacita')
# ('D', 'Deeble, W.')
# ('D', 'Degas, Edgar')
# ('D', 'Dehn, Adolf')
# ('D', 'Dekkers, Ad')
# ('D', 'Delamotte, William Alfred')
# ('D', 'Delaunay, Robert')
# ('D', 'Delaunay, Sonia')
# ('D', 'Deller, Jeremy')
# ('D', 'Delvaux, Paul')
# ('D', 'Demand, Thomas')
# ('D', 'Demnig, Gunter')
# ('D', 'Denham, John Charles')
# ('D', 'Denis, Dominic')
# ('D', 'Denner, Balthasar')
# ('D', 'Dennis, Jeffrey')
# ('D', 'Denny, Robyn')
# ('D', 'Dentith, Henry')
# ('D', 'Derain, André')
# ('D', 'Des Granges, David')
# ('D', 'Desnoyer, François')
# ('D', 'Despiau, Charles')
# ('D', 'Devas, Anthony')
# ('D', 'Deverell, Walter Howell')
# ('D', 'Devis, Anthony')
# ('D', 'Devis, Arthur')
# ('D', 'Devoto, John')
# ('D', 'Diaz Morales, Sebastian')
# ('D', 'Dibbets, Jan')
# ('D', 'Dick, Sir William Reid')
# ('D', 'Dickenson, Mark')
# ('D', 'Dicksee, Sir Frank')
# ('D', 'Diebenkorn, Richard')
# ('D', 'Dietman, Erik')
# ('D', 'Dighton, William Edward')
# ('D', 'Dijkstra, Rineke')
# ('D', 'Dillon, Michael')
# ('D', 'Dilworth, Norman')
# ('D', 'Dimitrienko, Pierre')
# ('D', 'Dimitrijevic, Braco')
# ('D', 'Dine, Jim')
# ('D', 'Dinkel, Ernest M.')
# ('D', 'Dion, Mark')
# ('D', 'Disler, Martin')
# ('D', 'Dismorr, Jessica')
# ('D', 'Dittborn, Eugenio')
# ('D', 'Dixon, Harry')
# ('D', 'Dixon, William')
# ('D', 'Dobson, Frank')
# ('D', 'Dobson, William')
# ('D', 'Dobson, William Charles Thomas')
# ('D', 'Dodd, Francis')
# ('D', 'Dodgson, John')
# ('D', 'Doesburg, Theo van')
# ('D', 'Doherty, Willie')
# ('D', 'Doig, Peter')
# ('D', 'Domjan, Joseph')
# ('D', 'Donagh, Rita')
# ('D', 'Donaldson, Andrew Brown')
# ('D', 'Donaldson, Antony')
# ('D', 'Donnelly, Trisha')
# ('D', 'Dorazio, Piero')
# ('D', 'Doron, Itai')
# ('D', 'Dotremont, Christian')
# ('D', 'Dottori, Gerardo')
# ('D', 'Doubleday, John')
# ('D', 'Doughty, William')
# ('D', 'Douglas, Edwin')
# ('D', 'Douglas, Sir William Fettes')
# ('D', 'Douglas, Stan')
# ('D', 'Dova, Gianni')
# ('D', 'Downard, Ebenezer Newman')
# ('D', 'Downman, John')
# ('D', 'Downsbrough, Peter')
# ('D', 'Downton, John')
# ('D', 'Doyle, John')
# ('D', 'Doyle, Richard')
# ('D', 'Draper, Herbert')
# ('D', 'Dressler, Conrad')
# ('D', 'Drever, Timothy')
# ('D', 'Drew, Leonardo')
# ('D', 'Droungas, Achilles')
# ('D', 'Drtikol, František')
# ('D', 'Drummond, Malcolm')
# ('D', 'Drury, Alfred')
# ('D', 'Drysdale, Russell')
# ('D', 'Du Bois, Simon')
# ('D', 'Dubsky, Mario')
# ('D', 'Dubuffet, Jean')
# ('D', 'Duchamp, Marcel')
# ('D', 'Duchamp-Villon, Raymond')
# ('D', 'Dufresne, Charles')
# ('D', 'Dufy, Raoul')
# ('D', 'Dugdale, Thomas')
# ('D', 'Dugger, John')
# ('D', 'Dumas, Marlene')
# ('D', 'Dunbar, Evelyn')
# ('D', 'Duncombe, Susanna')
# ('D', 'Dunham, Carroll')
# ('D', 'Dunker, Balthazar Anton')
# ('D', 'Dunlop, Ronald Ossory')
# ('D', 'Dunoyer de Segonzac, André')
# ('D', 'Dunstan, Bernard')
# ('D', 'Dupont, Gainsborough')
# ('D', 'Durant, Sam')
# ('D', 'Durham, Jimmie')
# ('D', 'Durrant, Jennifer')
# ('D', 'Durst, Alan L.')
# ('D', 'Dyce, William')
# ('D', 'Dzama, Marcel')
# ('D', 'Dzamonja, Dusan')
# ('D', 'Dörflinger, Johannes')
# ('E', 'EXPORT, VALIE')
# ('E', 'Eardley, Joan')
# ('E', 'Earnshaw, Anthony')
# ('E', 'East, Sir Alfred')
# ('E', 'Eastlake, Sir Charles Lock')
# ('E', 'Edmier, Keith')
# ('E', 'Edridge, Henry')
# ('E', 'Edwards, Edwin')
# ('E', 'Edwards, Jeffery')
# ('E', 'Egg, Augustus Leopold')
# ('E', 'Egley, William Maw')
# ('E', 'Ehrlich, Georg')
# ('E', 'El-Salahi, Ibrahim')
# ('E', 'Eliasson, Olafur')
# ('E', 'Elkoussy, Hala')
# ('E', 'Elliott, Geoffrey')
# ('E', 'Elmore, Alfred')
# ('E', 'Elwell, Frederick W.')
# ('E', 'Elwyn, John')
# ('E', 'Emanuel, Frank L.')
# ('E', 'Emett, Rowland')
# ('E', 'Emilian, Céline')
# ('E', 'Emin, Tracey')
# ('E', 'Eneroth, Joakim')
# ('E', 'Engelbach, Florence')
# ('E', 'English, Simon')
# ('E', 'Ensor, James')
# ('E', 'Epstein, Mitch')
# ('E', 'Epstein, Sir Jacob')
# ('E', "Erlanger, Rodolphe d'")
# ('E', 'Erma, Thomas')
# ('E', 'Ernest, John')
# ('E', 'Ernst, Max')
# ('E', 'Errazuriz, Paz')
# ('E', 'Erté')
# ('E', 'Erwitt, Elliot')
# ('E', 'Eskandarfar, Samira')
# ('E', 'Espaliú, Pepe')
# ('E', 'Essenhigh, Inka')
# ('E', 'Essex, Lord')
# ('E', 'Estes, Richard')
# ('E', 'Estève, Maurice')
# ('E', 'Etchells, Frederick')
# ('E', 'Etrog, Sorel')
# ('E', 'Etty, William')
# ('E', 'Eurich, Richard')
# ('E', 'Evans, Garth')
# ('E', 'Evans, Jason')
# ('E', 'Evans, Merlyn Oliver')
# ('E', 'Evans, Sebastian')
# ('E', 'Eves, Reginald G')
# ('E', 'Ewan, Ruth')
# ('E', 'Eworth, Hans')
# ('E', 'Eyton, Anthony')
# ('F', 'Fabro, Luciano')
# ('F', 'Faed, Thomas')
# ('F', 'Fagan, Robert')
# ('F', 'Fahlström, Öyvind')
# ('F', 'Fairhurst, Angus')
# ('F', 'Fairweather, Ian')
# ('F', 'Falkenstein, Claire')
# ('F', 'Fantin-Latour, Henri')
# ('F', 'Farington, Joseph')
# ('F', 'Farquharson, David')
# ('F', 'Farquharson, Joseph')
# ('F', 'Farreras, Francisco')
# ('F', 'Fast, Omer')
# ('F', 'Fautrier, Jean')
# ('F', 'Fazzini, Pericle')
# ('F', 'Fearon, Hilda')
# ('F', 'Fedden, Mary')
# ('F', 'Federle, Helmut')
# ('F', 'Fehr, Henry C')
# ('F', 'Feibusch, Hans')
# ('F', 'Feiler, Jo')
# ('F', 'Feiler, Paul')
# ('F', 'Feldmann, Hans-Peter')
# ('F', 'Fell, Sheila')
# ('F', 'Ferguson, William Gow')
# ('F', 'Fergusson, J.D.')
# ('F', 'Ferneley, John, I')
# ('F', 'Ferneley, John, II')
# ('F', 'Ferrari, León')
# ('F', 'Ferrers, Benjamin')
# ('F', 'Ferris, Dee')
# ('F', 'Few, Elsie')
# ('F', 'Fielding, Anthony Vandyke Copley')
# ('F', 'Fielding, Brian')
# ('F', 'Fijalkowski, Stanislaw')
# ('F', 'Fildes, Sir Luke')
# ('F', 'Finch, Francis Oliver')
# ('F', 'Finden, William')
# ('F', 'Fine, Lois')
# ('F', 'Fini, Leonor')
# ('F', 'Finn, Michael')
# ('F', 'Finn-Kelcey, Rose')
# ('F', 'Finnie, John')
# ('F', 'Fischli, Peter')
# ('F', 'Fisher, Brian')
# ('F', 'Fisher, Joel')
# ('F', 'Fisher, Mark')
# ('F', 'Fisher, Melton')
# ('F', 'Fisher, Roy')
# ('F', 'Fitton, James')
# ('F', 'Fitzgerald, John Anster')
# ('F', 'Flanagan, Barry')
# ('F', 'Flavin, Dan')
# ('F', 'Flaxman, John')
# ('F', 'Florence, Mary Sargant')
# ('F', 'Floyer, Ceal')
# ('F', 'Foley, John Henry')
# ('F', 'Fontana, Lucio')
# ('F', 'Forain, Jean-Louis')
# ('F', 'Forbes, Elizabeth')
# ('F', 'Forbes, Stanhope Alexander')
# ('F', 'Forbes, Vivian')
# ('F', 'Forbes-Robertson, Eric')
# ('F', 'Ford, Edward Onslow')
# ('F', 'Ford, Laura')
# ('F', 'Ford, Mary')
# ('F', 'Forge, Andrew')
# ('F', 'Forsyth, Iain')
# ('F', 'Fosso, Samuel')
# ('F', 'Foster, Myles Birket')
# ('F', 'Foster, William')
# ('F', 'Fougeron, André')
# ('F', 'Fowler, Luke')
# ('F', 'Fox Pitt, Douglas')
# ('F', 'Fraenkel, Elsa')
# ('F', 'Frampton, Edward Reginald')
# ('F', 'Frampton, Meredith')
# ('F', 'Frampton, Sir George')
# ('F', 'Francia, François Louis Thomas')
# ('F', 'Francis, Mark')
# ('F', 'Francis, Sam')
# ('F', 'Frank, Robert')
# ('F', 'Frankenthaler, Helen')
# ('F', 'Fraser, Alexander')
# ('F', 'Fraser, Andrea')
# ('F', 'Fraser, Claud Lovat')
# ('F', 'Freedman, Barnett')
# ('F', 'Freiles, Antonio')
# ('F', 'French School 18th century')
# ('F', 'Frenkel, Vera')
# ('F', 'Freud, Lucian')
# ('F', 'Friedenson, Arthur')
# ('F', 'Friedlander, Lee')
# ('F', 'Friend, Ian')
# ('F', 'Friesz, Othon')
# ('F', 'Frink, Dame Elisabeth')
# ('F', 'Fripp, Alfred Downing')
# ('F', 'Fripp, George Arthur')
# ('F', 'Frith, William Powell')
# ('F', 'Frize, Bernard')
# ('F', 'Frohner, Adolf')
# ('F', 'Frost, Sir Terry')
# ('F', 'Frost, William Edward')
# ('F', 'Froy, Martin')
# ('F', 'Fry, Anthony')
# ('F', 'Fry, Roger')
# ('F', 'Frye, Thomas')
# ('F', 'Frélaut, Jean')
# ('F', 'Fuchs, Emil')
# ('F', 'Fukushima, Hideko')
# ('F', 'Fullard, George')
# ('F', 'Fuller, Isaac')
# ('F', 'Fuller, Sue')
# ('F', 'Fulleylove, John')
# ('F', 'Fulton, Hamish')
# ('F', 'Furlong, William')
# ('F', 'Furse, Charles Wellington')
# ('F', 'Fuseli, Henry')
# ('F', 'Fussell, Michael')
# ('F', 'Fyzee-Rahamin, Samuel')
# ('F', 'Förg, Günther')
# ('G', 'Gabie, Neville')
# ('G', 'Gabo, Naum')
# ('G', 'Gainsborough, Thomas')
# ('G', 'Gale, William')
# ('G', 'Gallaccio, Anya')
# ('G', 'Gallagher, Ellen')
# ('G', 'Gamarra, Sandra')
# ('G', 'Gander, Ryan')
# ('G', 'Garaicoa, Carlos')
# ('G', 'Garbe, Richard')
# ('G', 'Garcia Torres, Mario')
# ('G', 'Gardiner, Clive')
# ('G', 'Gardner, Daniel')
# ('G', 'Garet, Jedd')
# ('G', 'Garrard, George')
# ('G', 'Garstin, Norman')
# ('G', 'Gascoyne, David')
# ('G', 'Gaskell, Anna')
# ('G', 'Gastineau, Henry')
# ('G', 'Gaudier-Brzeska, Henri')
# ('G', 'Gauguin, Paul')
# ('G', 'Gauld, Peter')
# ('G', 'Gear, William')
# ('G', 'Geddes, Andrew')
# ('G', 'Geden, Dennis')
# ('G', 'Gego (Gertrud Goldschmidt)')
# ('G', 'Geikie, Walter')
# ('G', 'Gennari, Benedetto')
# ('G', 'Gent, G.W.')
# ('G', 'Gentleman, David')
# ('G', 'Gentleman, Tom')
# ('G', 'Genzken, Isa')
# ('G', 'Geoffrey, Iqbal')
# ('G', 'George, Patrick')
# ('G', 'George, Thomas')
# ('G', 'Gere, Charles M.')
# ('G', 'Gere, Margaret')
# ('G', 'Gerrard, A.H.')
# ('G', 'Gerrard, Kathleen')
# ('G', 'Gersht, Ori')
# ('G', 'Gershuni, Moshe')
# ('G', 'Gertler, Mark')
# ('G', 'Gethin, Percy Francis')
# ('G', 'Gheeraerts, Marcus, II')
# ('G', 'Ghika, Nicolas')
# ('G', 'Giacometti, Alberto')
# ('G', 'Giardelli, Arthur')
# ('G', 'Gibb, Phelan')
# ('G', 'Gibbons, John')
# ('G', 'Gibbs, Evelyn')
# ('G', 'Gibbs, Ewan')
# ('G', 'Gibbs, Henry')
# ('G', 'Gibson, John')
# ('G', 'Gidal, Tim')
# ('G', 'Gilbert & George')
# ('G', 'Gilbert, Charles Web')
# ('G', 'Gilbert, Sir Alfred')
# ('G', 'Gilbert, Sir John')
# ('G', 'Gilbert, Stephen')
# ('G', 'Gilioli, Emile')
# ('G', 'Gill, Charles')
# ('G', 'Gill, Colin')
# ('G', 'Gill, Eric')
# ('G', 'Gill, Macdonald')
# ('G', 'Gilliam, Sam')
# ('G', 'Gillick, Liam')
# ('G', 'Gillies, Sir William')
# ('G', 'Gillray, James')
# ('G', 'Gilman, Harold')
# ('G', 'Gilpin, Rev. William')
# ('G', 'Gilpin, Sawrey')
# ('G', 'Ginesi, Edna')
# ('G', 'Ginger, Phyllis')
# ('G', 'Ginner, Charles')
# ('G', 'Giobbi, Edward')
# ('G', 'Girtin, Thomas')
# ('G', 'Gleichen, Feodora')
# ('G', 'Gleizes, Albert')
# ('G', 'Glendening, Alfred')
# ('G', 'Glendenning, Ronald')
# ('G', 'Glover, John')
# ('G', 'Gober, Robert')
# ('G', 'Goeneutte, Norbert')
# ('G', 'Goeritz, Mathias')
# ('G', 'Gogh, Vincent van')
# ('G', 'Golden, Grace')
# ('G', 'Goldin, Nan')
# ('G', 'Golding, John')
# ('G', 'Goldschmidt, Hilde')
# ('G', 'Goldsworthy, Andy')
# ('G', 'Golub, Leon')
# ('G', 'Gomes, Fernanda')
# ('G', 'Goncharova, Natalya')
# ('G', 'Gonzalez-Foerster, Dominique')
# ('G', 'Gonzalez-Torres, Felix')
# ('G', 'González, Joan')
# ('G', 'González, Julio')
# ('G', 'Good, Thomas Sword')
# ('G', 'Goodall, Edward Angelo')
# ('G', 'Goodall, Frederick')
# ('G', 'Goodwin, Albert')
# ('G', 'Gordine, Dora')
# ('G', 'Gordon, Douglas')
# ('G', 'Gordon, Julia Emily')
# ('G', 'Gordon, Lady')
# ('G', 'Gordon, Sir Harry Percy, 2nd Bt')
# ('G', 'Gordon, Sir John Watson')
# ('G', 'Gore, Charles')
# ('G', 'Gore, Spencer')
# ('G', 'Gorky, Arshile')
# ('G', 'Gormley, Antony')
# ('G', 'Gosse, Sylvia')
# ('G', 'Gotch, Thomas Cooper')
# ('G', 'Gotlib, Henryk')
# ('G', 'Gottlieb, Adolph')
# ('G', 'Gouk, Alan')
# ('G', 'Gow, Andrew Carrick')
# ('G', 'Gow, Mary')
# ('G', 'Gower, George')
# ('G', 'Gowing, Sir Lawrence')
# ('G', 'Graeser, Camille')
# ('G', 'Graevenitz, Gerhard von')
# ('G', 'Graham, Dan')
# ('G', 'Graham, Paul')
# ('G', 'Graham, Peter')
# ('G', 'Graham, Rodney')
# ('G', 'Grand, Roger')
# ('G', 'Grant, Alistair')
# ('G', 'Grant, Duncan')
# ('G', 'Grant, Sir Francis')
# ('G', 'Grassie, Andrew')
# ('G', 'Grau, Enrique')
# ('G', 'Gravelot, Hubert François')
# ('G', 'Graveney, William')
# ('G', 'Graves, Morris')
# ('G', 'Gray, Douglas S.')
# ('G', 'Gray, Ronald')
# ('G', 'Grayson, Roy')
# ('G', 'Greaves, Derrick')
# ('G', 'Greaves, Walter')
# ('G', 'Greco, Emilio')
# ('G', 'Green, Alan')
# ('G', 'Green, Anthony')
# ('G', 'Green, Jesse')
# ('G', 'Green, William')
# ('G', 'Greene, Stephen')
# ('G', 'Greenfield, Graham')
# ('G', 'Greenham, Peter')
# ('G', 'Greenwood, Philip')
# ('G', 'Gregory, Edward John')
# ('G', 'Greiffenhagen, Maurice')
# ('G', 'Greville, Lady Louisa')
# ('G', 'Griffier, Jan, I')
# ('G', 'Griffiths, Brian')
# ('G', 'Griffiths, John')
# ('G', 'Grimm, Samuel Hieronymous')
# ('G', 'Grimonprez, Johan')
# ('G', 'Grimshaw, Atkinson')
# ('G', 'Grimshaw, Trevor')
# ('G', 'Grippo, Victor')
# ('G', 'Gris, Juan')
# ('G', 'Gross, Anthony')
# ('G', 'Gross, Michael')
# ('G', 'Grosz, George')
# ('G', 'Groth, Jan')
# ('G', 'Gruber, Francis')
# ('G', 'Grubic, Igor')
# ('G', 'Guerrilla Girls')
# ('G', 'Guevara, Alvaro')
# ('G', 'Guevara, Meraud')
# ('G', 'Guillaumin, Armand')
# ('G', 'Gulich, John')
# ('G', 'Gunn, Sir Herbert James')
# ('G', 'Gunning, Lucy')
# ('G', 'Guo-Qiang, Cai')
# ('G', 'Gupta, Subodh')
# ('G', 'Gurschner, Herbert')
# ('G', 'Gursky, Andreas')
# ('G', 'Gusmão, João Maria')
# ('G', 'Gussin, Graham')
# ('G', 'Guston, Philip')
# ('G', 'Gutfreund, Oto')
# ('G', 'Guthrie, Robin')
# ('G', 'Guthrie, Sir James')
# ('G', 'Guttuso, Renato')
# ('G', 'Gwynne-Jones, Allan')
# ('G', 'Gyles, Henry')
# ('G', 'Götz, Professor Karl-Otto')
# ('H', 'Haacke, Hans')
# ('H', 'Hacker, Arthur')
# ('H', 'Hackert, Jacob Philippe')
# ('H', 'Haden, Sir Francis Seymour')
# ('H', 'Haerizadeh, Rokni')
# ('H', 'Haese, Günther')
# ('H', 'Haghe, Louis')
# ('H', 'Haile, Sam')
# ('H', 'Hakewill, James')
# ('H', 'Hall, David')
# ('H', 'Hall, Harry')
# ('H', 'Hall, Nigel')
# ('H', 'Hall, Oliver')
# ('H', 'Halliday, Edward')
# ('H', 'Halswelle, Keeley')
# ('H', 'Hamada, Shoji')
# ('H', 'Hambling, Maggi')
# ('H', 'Hamilton Finlay, Ian')
# ('H', 'Hamilton, Ann')
# ('H', 'Hamilton, Anthea')
# ('H', 'Hamilton, Cuthbert')
# ('H', 'Hamilton, Gavin')
# ('H', 'Hamilton, Gawen')
# ('H', 'Hamilton, James')
# ('H', 'Hamilton, Richard')
# ('H', 'Hamilton, William')
# ('H', 'Hammershoi, Vilhelm')
# ('H', 'Hammons, David')
# ('H', 'Hancock, Charles')
# ('H', 'Hand, Thomas')
# ('H', 'Hapaska, Siobhán')
# ('H', 'Hardaker, Charles')
# ('H', 'Hardie, Martin')
# ('H', 'Harding, James Duffield')
# ('H', 'Harding, The Hon. Charles Stewart, Viscount')
# ('H', 'Harris, John')
# ('H', 'Harrison, Margaret')
# ('H', 'Harrison, Paul')
# ('H', 'Hart, James Turpin')
# ('H', 'Hart, Solomon Alexander')
# ('H', 'Hartley, Mary, of Bath')
# ('H', 'Hartrick, Archibald Standish')
# ('H', 'Hartung, Hans')
# ('H', 'Hartwell, Charles Leonard')
# ('H', 'Haseltine, Herbert')
# ('H', 'Hashmi, Zarina')
# ('H', 'Hassell, John')
# ('H', 'Hatakeyama, Naoya')
# ('H', 'Hatherell, William')
# ('H', 'Hatoum, Mona')
# ('H', 'Haughton, Matthew')
# ('H', 'Haughton, Moses, the Elder')
# ('H', 'Hausmann, Raoul')
# ('H', 'Havekost, Eberhard')
# ('H', 'Havell, William')
# ('H', 'Haworth, Jann')
# ('H', 'Hayden, Henri')
# ('H', 'Haydon, Benjamin Robert')
# ('H', 'Hayes, Edwin')
# ('H', 'Hayls, John')
# ('H', 'Hayman, Francis')
# ('H', 'Hayman, Patrick')
# ('H', 'Haynes-Williams, John')
# ('H', 'Hays, Dan')
# ('H', 'Hayter, John')
# ('H', 'Hayter, Sir George')
# ('H', 'Hayter, Stanley William')
# ('H', 'Hayward, Alfred Robert')
# ('H', 'Head, Tim')
# ('H', 'Heaphy, Thomas')
# ('H', 'Hearne, Thomas')
# ('H', 'Heath, Adrian')
# ('H', 'Heath, Henry')
# ('H', 'Hegedusic, Krsto')
# ('H', 'Heiliger, Bernhard')
# ('H', 'Hein, Jeppe')
# ('H', 'Heindorff, Michael')
# ('H', 'Heinzmann, Thilo')
# ('H', 'Heizer, Michael')
# ('H', 'Held, Al')
# ('H', 'Helleu, Paul')
# ('H', 'Helman, Robert')
# ('H', 'Hemy, Charles Napier')
# ('H', 'Henderson, Charles Cooper')
# ('H', 'Henderson, Elsie Marian')
# ('H', 'Henderson, John')
# ('H', 'Henderson, Nigel')
# ('H', 'Henderson, William')
# ('H', 'Henderson-Begg, Liselott')
# ('H', 'Hennell, Thomas')
# ('H', 'Henri, Robert')
# ('H', 'Henry, Paul')
# ('H', 'Hepher, David')
# ('H', 'Hepworth, Dame Barbara')
# ('H', 'Herbert, J.G.S.')
# ('H', 'Herbert, John Rogers')
# ('H', 'Herbin, Auguste')
# ('H', 'Herman, Andrew')
# ('H', 'Herman, Josef')
# ('H', 'Hermes, Gertrude')
# ('H', 'Herold, Georg')
# ('H', 'Heron, Patrick')
# ('H', 'Herrera, Arturo')
# ('H', 'Herrera, Carmen')
# ('H', 'Herring, Ed')
# ('H', 'Herring, John Frederick')
# ('H', 'Herring, John Frederick, Junior')
# ('H', 'Hershman, Lynn')
# ('H', 'Hervé, Lucien')
# ('H', 'Hesse, Eva')
# ('H', 'Heyboer, Anton')
# ('H', 'Hickey, Thomas')
# ('H', 'Hicks, George Elgar')
# ('H', 'Hicks, Philip')
# ('H', 'Hide, Peter')
# ('H', 'Higgs, Matthew')
# ('H', 'Highmore')
# ('H', 'Highmore, Joseph')
# ('H', 'Hilditch, Richard H.')
# ('H', 'Hill, Anthony')
# ('H', 'Hill, Derek')
# ('H', 'Hill, Gary')
# ('H', 'Hill, John')
# ('H', 'Hiller, Susan')
# ('H', 'Hilliard, John')
# ('H', 'Hillier, Tristram')
# ('H', 'Hills, Robert')
# ('H', 'Hilton, Roger')
# ('H', 'Hilton, William, the Younger')
# ('H', 'Himid, Lubaina')
# ('H', 'Hine, Lewis')
# ('H', 'Hiorns, Roger')
# ('H', 'Hirata, Minoru')
# ('H', 'Hirschhorn, Thomas')
# ('H', 'Hirst, Damien')
# ('H', 'Hirst, Derek')
# ('H', 'Hitchens, Ivon')
# ('H', 'Hlobo, Nicholas')
# ('H', 'Hoare, Prince')
# ('H', 'Hoare, Sir Richard Colt')
# ('H', 'Hoare, William')
# ('H', 'Hobbs, Peter')
# ('H', 'Hockney, David')
# ('H', 'Hodges, Jim')
# ('H', 'Hodges, William')
# ('H', 'Hodgkin, Eliot')
# ('H', 'Hodgkin, Howard')
# ('H', 'Hodgkins, Frances')
# ('H', 'Hofland, Thomas Christopher')
# ('H', 'Hoflehner, Rudolf')
# ('H', 'Hofmann, Hans')
# ('H', 'Hogarth, Paul')
# ('H', 'Hogarth, William')
# ('H', 'Hokanson, Lars')
# ('H', 'Holden, Cliff')
# ('H', 'Holdsworth, Dan')
# ('H', 'Holl, Frank')
# ('H', 'Holland, Harry')
# ('H', 'Holland, James')
# ('H', 'Holloway, Charles Edward')
# ('H', 'Hollweg, Alexander')
# ('H', 'Holman, Francis')
# ('H', 'Holmes, Sir Charles John')
# ('H', 'Holmes, Sir Richard Rivington')
# ('H', 'Holroyd, Sir Charles')
# ('H', 'Holst, Theodor von')
# ('H', 'Holt, Lilian')
# ('H', 'Holworthy, James')
# ('H', 'Holyhead, Robert')
# ('H', 'Holzer, Jenny')
# ('H', 'Hone, Evie')
# ('H', 'Hone, Nathaniel')
# ('H', 'Hook, Dr Richard')
# ('H', 'Hook, James Clarke')
# ('H', 'Hoppner, John')
# ('H', 'Hopton, Georgie')
# ('H', 'Hopwood, Henry Silkstone')
# ('H', 'Hore, Somnath')
# ('H', 'Hori, Fusao')
# ('H', 'Horn, Rebecca')
# ('H', 'Horn, Roni')
# ('H', 'Hornel, Edward Atkinson')
# ('H', 'Horsfield, Craigie')
# ('H', 'Horsley, John Callcott')
# ('H', 'Horton, Percy')
# ('H', 'Hoskin, John')
# ('H', 'Houghton, Arthur Boyd')
# ('H', 'House, Gordon')
# ('H', 'Houshiary, Shirazeh')
# ('H', 'Housman, Laurence')
# ('H', 'Houthuesen, Albert')
# ('H', 'How, Beatrice')
# ('H', 'Howard, Henry')
# ('H', 'Howell, Peter')
# ('H', 'Howitt, Samuel')
# ('H', 'Howson, Peter')
# ('H', 'Hoyland, John')
# ('H', 'Hubbard, John')
# ('H', 'Hubert, Edgar')
# ('H', 'Hudson, Anna Hope')
# ('H', 'Hudson, Thomas')
# ('H', 'Huebler, Douglas')
# ('H', 'Huggins, William')
# ('H', 'Hughes, Arthur')
# ('H', 'Hughes, Malcolm')
# ('H', 'Hughes, Patrick')
# ('H', 'Hughes-Stanton, Blair')
# ('H', 'Hughes-Stanton, Sir Herbert')
# ('H', 'Hugonin, James')
# ('H', 'Hulbert, Thelma')
# ('H', 'Hullmandel, Charles')
# ('H', 'Hulusi, Mustafa')
# ('H', 'Hume, Gary')
# ('H', 'Humphry, Ozias')
# ('H', 'Huner, Emre')
# ('H', 'Hunt, Alfred William')
# ('H', 'Hunt, Walter')
# ('H', 'Hunt, William Henry')
# ('H', 'Hunt, William Holman')
# ('H', 'Hunter, Colin')
# ('H', 'Hunter, Leslie')
# ('H', 'Hurlstone, Frederick Yeates')
# ('H', 'Hurry, Leslie')
# ('H', 'Huskisson, Robert')
# ('H', 'Hussey, Giles')
# ('H', 'Hutchinson, Louise')
# ('H', 'Hutton, Clarke')
# ('H', 'Huws, Bethan')
# ('H', 'Huxley, Paul')
# ('H', 'Huyghe, Pierre')
# ('H', 'Huysmans, Jacob')
# ('H', 'Hélion, Jean')
# ('H', 'Höfer, Candida')
# ('H', 'Höller, Carsten')
# ('I', 'Ibbetson, Julius Caesar')
# ('I', 'Iglesias, Cristina')
# ('I', 'Illes, Arpad')
# ('I', 'Immendorff, Jörg')
# ('I', 'Ince, Evelyn')
# ('I', 'Ince, Joseph Murray')
# ('I', 'Inchbold, John William')
# ('I', 'Indiana, Robert')
# ('I', 'Inlander, Henry')
# ('I', 'Innes, Callum')
# ('I', 'Innes, James Dickson')
# ('I', 'Inshaw, David')
# ('I', 'International Local (Sarah Charlesworth; Joseph Kosuth; Anthony McCall)')
# ('I', 'Inventory')
# ('I', 'Ipoustéguy, Jean')
# ('I', 'Ireland, Geoffrey')
# ('I', 'Ironside, Robin')
# ('I', 'Irvin, Albert')
# ('I', 'Irvine, Jaki')
# ('I', 'Irwin, Gwyther')
# ('I', 'Islam, Runa')
# ('I', 'Italian or German (?) School 17th century')
# ('I', 'Ivekovic, Sanja')
# ('J', 'Jaar, Alfredo')
# ('J', 'Jack, Richard')
# ('J', 'Jacklin, Bill')
# ('J', 'Jackson, Alexander Young')
# ('J', 'Jackson, Arthur')
# ('J', 'Jackson, F. Ernest')
# ('J', 'Jackson, Gilbert')
# ('J', 'Jackson, John')
# ('J', 'Jackson, Melanie')
# ('J', 'Jackson, Samuel Phillips')
# ('J', 'Jacobs, Janice')
# ('J', 'Jacovleff, Alexandre')
# ('J', 'Jagger, Charles Sargeant')
# ('J', 'James, A. Gosset')
# ('J', 'Jamieson, Alexander')
# ('J', 'Janas, Piotr')
# ('J', 'Janecek, Ota')
# ('J', 'Jankowski, Christian')
# ('J', 'Janowich, Ron')
# ('J', 'Jansen, Angela')
# ('J', 'Janssen, Horst')
# ('J', 'Jantjes, Gavin')
# ('J', 'Japp, Darsie')
# ('J', 'Jaray, Tess')
# ('J', 'Jarman, Derek')
# ('J', 'Jefferys, James')
# ('J', 'Jemec, Andrej')
# ('J', 'Jenkins, Paul')
# ('J', 'Jennings, Humphrey')
# ('J', 'Jennings, William George')
# ('J', 'Jensen, Bill')
# ('J', 'Jensen, Sergej')
# ('J', 'Jesih, Boris')
# ('J', 'Jess')
# ('J', 'John')
# ('J', 'John, Augustus, OM')
# ('J', 'John, Gwen')
# ('J', 'John, Richard Johnny')
# ('J', 'John, Sir William Goscombe')
# ('J', 'Johns, Jasper')
# ('J', 'Johnson, Ben')
# ('J', 'Johnson, Charles Edward')
# ('J', 'Johnson, Cornelius')
# ('J', 'Johnson, James')
# ('J', 'Johnson, Ray')
# ('J', 'Johnson, Thomas')
# ('J', 'Johnstone, William')
# ('J', 'Jonas, Joan')
# ('J', 'Jones, Allen')
# ('J', 'Jones, Barbara')
# ('J', 'Jones, David')
# ('J', 'Jones, Fred Cecil')
# ('J', 'Jones, Gareth')
# ('J', 'Jones, George')
# ('J', 'Jones, Harold')
# ('J', 'Jones, Sarah')
# ('J', 'Jones, Stanley')
# ('J', 'Jones, Thomas')
# ('J', 'Jones, William')
# ('J', 'Jones, Zebedee')
# ('J', 'Jonzen, Karin')
# ('J', 'Joreige, Lamia')
# ('J', 'Jorn, Asger')
# ('J', 'Joseph, Lily D.')
# ('J', 'Joseph, Peter')
# ('J', 'Joseph, Samuel')
# ('J', 'Joy, William')
# ('J', 'Joyce, Paul')
# ('J', 'Judd, Donald')
# ('J', 'Julien, Isaac')
# ('J', 'Jungman, Nico')
# ('J', 'Just, Jesper')
# ('K', 'Kabakov, Ilya')
# ('K', 'Kadishman, Menashe')
# ('K', 'Kahn, Erich')
# ('K', 'Kaisermann, Franz')
# ('K', 'Kandinsky, Wassily')
# ('K', 'Kanovitz, Howard')
# ('K', 'Kapoor, Anish')
# ('K', 'Karamustafa, Gulsun')
# ('K', 'Karshan, Linda')
# ('K', 'Katz, Alex')
# ('K', 'Kauffman, Angelica')
# ('K', 'Kauffman, Craig')
# ('K', 'Kaufmann, Isidor')
# ('K', 'Kavanagh, John F.')
# ('K', 'Kawara, On')
# ('K', 'Kay, Emma')
# ('K', 'Keen, Jeff')
# ('K', 'Keene, Charles Samuel')
# ('K', 'Keeping, Charles')
# ('K', 'Keirincx, Alexander')
# ('K', 'Kelly, Ellsworth')
# ('K', 'Kelly, Felix')
# ('K', 'Kelly, Francis')
# ('K', 'Kelly, Mary')
# ('K', 'Kelly, Sir Gerald')
# ('K', 'Kelm, Annette')
# ('K', 'Kemeny, Zoltan')
# ('K', 'Kemp-Welch, Lucy')
# ('K', 'Kennard, Peter')
# ('K', 'Kennet, Lady')
# ('K', 'Kennington, Eric')
# ('K', 'Kennington, Thomas Benjamin')
# ('K', 'Kenny, Michael')
# ('K', 'Kentridge, William')
# ('K', 'Kerr, Charles Henry Malcolm')
# ('K', 'Kerr-Lawson, James')
# ('K', 'Kerrich, Thomas')
# ('K', 'Kessell, Mary')
# ('K', 'Kestelman, Morris')
# ('K', 'Kettle, Tilly')
# ('K', 'Key, Joan')
# ('K', 'Khakhar, Bhupen')
# ('K', 'Kher, Bharti')
# ('K', 'Kiaer, Ian')
# ('K', 'Kidner, Michael')
# ('K', 'Kiefer, Anselm')
# ('K', 'Kienholz, Edward')
# ('K', 'Kiff, Ken')
# ('K', 'Kilpper, Thomas')
# ('K', 'Kindersley, David')
# ('K', 'King, Cecil')
# ('K', 'King, Jeremy')
# ('K', 'King, John Henry Yeend')
# ('K', 'King, Phillip')
# ('K', 'King, Ronald')
# ('K', 'King, Scott')
# ('K', 'Kinley, Peter')
# ('K', 'Kinnard, W.')
# ('K', 'Kippenberger, Martin')
# ('K', 'Kirchner, Ernst Ludwig')
# ('K', 'Kirk, Eve')
# ('K', 'Kirkeby, Per')
# ('K', 'Kitadai, Shozo')
# ('K', 'Kitaj, R.B.')
# ('K', 'Klee, Paul')
# ('K', 'Klein, Astrid')
# ('K', 'Klein, Jochen')
# ('K', 'Klein, Yves')
# ('K', 'Kline, Franz')
# ('K', 'Klinghoffer, Clara')
# ('K', 'Klossowski de Rola, Balthus')
# ('K', 'Kneale, Bryan')
# ('K', 'Kneller, Sir Godfrey')
# ('K', 'Knight, Charles Parsons')
# ('K', 'Knight, Dame Laura')
# ('K', 'Knight, Harold')
# ('K', 'Knight, John Baverstock')
# ('K', 'Knight, John Prescott')
# ('K', 'Knight, John William Buxton')
# ('K', 'Knight, Joseph')
# ('K', 'Knights, Winifred')
# ('K', 'Knowles, Justin')
# ('K', 'Koch, Eleanor')
# ('K', 'Koenig, Ghisha')
# ('K', 'Kohn, Misch')
# ('K', 'Kokoschka, Oskar')
# ('K', 'Koller, Július')
# ('K', 'Kolár, Jirí')
# ('K', 'Kolárová, Bela')
# ('K', 'Kolíbal, Stanislav')
# ('K', 'Komatsu, André')
# ('K', 'Komura, Kiyohiko')
# ('K', 'Konzal, Joseph')
# ('K', 'Koo, Jeong-A')
# ('K', 'Kooning, Willem de')
# ('K', 'Koons, Jeff')
# ('K', 'Koppel, Heinz')
# ('K', 'Kopystiansky, Igor')
# ('K', 'Korner, John')
# ('K', 'Koshimizu, Susumu')
# ('K', 'Kossoff, Leon')
# ('K', 'Kosuth, Joseph')
# ('K', 'Kounellis, Jannis')
# ('K', 'Kovanda, Jiri')
# ('K', 'Kramer, Harry')
# ('K', 'Kramer, Jacob')
# ('K', 'Krasinski, Edward')
# ('K', 'Krasner, Lee')
# ('K', 'Krsinic, Frano')
# ('K', 'Kruger, Barbara')
# ('K', 'Krzywoblocki, Wojciech')
# ('K', 'Kudryashov, Oleg')
# ('K', 'Kuitca, Guillermo')
# ('K', 'Kulmer, Ferdinand')
# ('K', 'Kunkel, Don')
# ('K', 'Kunst, Mauro')
# ('K', 'Kuper, Roi')
# ('K', 'Kupka, Frantisek')
# ('K', 'Kuri, Gabriel')
# ('K', 'Kusama, Yayoi')
# ('K', 'Kushner, Robert')
# ('K', 'KwieKulik')
# ('L', 'La Dell, Edwin')
# ('L', 'La Noue, Terence')
# ('L', 'La Thangue, Henry Herbert')
# ('L', 'Laabs, Hans')
# ('L', 'Labruzzi, Carlo')
# ('L', 'Lacey, Bruce')
# ('L', 'Ladbrooke, Robert')
# ('L', 'Laidlay, William James')
# ('L', 'Laing, Gerald')
# ('L', 'Laing, J.S.')
# ('L', 'Lairesse')
# ('L', 'Lalic, Maria')
# ('L', 'Lam, Wifredo')
# ('L', 'Lamb, Henry')
# ('L', 'Lamb, Lynton')
# ('L', 'Lambert')
# ('L', 'Lambert, George')
# ('L', 'Lambert, James')
# ('L', 'Lambert, Maurice')
# ('L', 'Lambie, Jim')
# ('L', 'Lambourn, George')
# ('L', 'Lamelas, David')
# ('L', 'Lancaster, Mark')
# ('L', 'Lancaster, Osbert')
# ('L', 'Lancaster, Rev. Richard Hume')
# ('L', 'Lance, George')
# ('L', 'Lanceley, Colin')
# ('L', 'Lander, Reginald')
# ('L', 'Landers, Sean')
# ('L', 'Landsaat, Hans')
# ('L', 'Landseer, Charles')
# ('L', 'Landseer, Sir Edwin Henry')
# ('L', 'Landy, Michael')
# ('L', 'Lane, Abigail')
# ('L', 'Lane, Samuel')
# ('L', 'Lane, Theodore')
# ('L', 'Lang, Daniel')
# ('L', 'Lange, Dorothea')
# ('L', 'Langlands and Bell, Ben and Nikki')
# ('L', 'Langlois, Denis')
# ('L', 'Lanteri, Edouard')
# ('L', 'Lanyon, Peter')
# ('L', 'Laporte, George Henry')
# ('L', 'Laporte, John')
# ('L', 'Large, Valerie')
# ('L', 'Larionov, Michel')
# ('L', 'Laroon, Marcellus, the Younger')
# ('L', 'Lartigue, Jacques-Henri')
# ('L', 'Latham, James')
# ('L', 'Latham, John')
# ('L', 'Lattanzi, Luciano')
# ('L', 'Laurence, Samuel')
# ('L', 'Laurencin, Marie')
# ('L', 'Laurens, Henri')
# ('L', 'Laurie, Robin')
# ('L', 'Lausen, Jens')
# ('L', 'Lavery, Sir John')
# ('L', 'Law, Alfred')
# ('L', 'Law, Bob')
# ('L', 'Lawes-Wittewronge, Sir Charles, Bt')
# ('L', 'Lawler, Louise')
# ('L', 'Lawrence, Eileen')
# ('L', 'Lawrence, Sir Thomas')
# ('L', 'Lawson, Cecil')
# ('L', 'Lawson, Thomas')
# ('L', 'Le Bas, Edward')
# ('L', 'Le Brocquy, Louis')
# ('L', 'Le Brun, Christopher, PRA')
# ('L', 'Le Capelain, Jean')
# ('L', 'Le Corbusier')
# ('L', 'Le Parc, Julio')
# ('L', 'Le Piper, Francis')
# ('L', 'Le Sidaner, Henri')
# ('L', 'Le Witt, Jan')
# ('L', 'LeWitt, Sol')
# ('L', 'Leach, Bernard')
# ('L', 'Leach, David')
# ('L', 'Leach, Janet')
# ('L', 'Leader, Benjamin Williams')
# ('L', 'Leaman, Jonathan')
# ('L', 'Leapman, Edwina')
# ('L', 'Lear, Edward')
# ('L', 'Leck, Bart van der')
# ('L', 'Leckey, Mark')
# ('L', 'Ledger, Janet')
# ('L', 'Ledward, Gilbert')
# ('L', 'Lee, Catherine')
# ('L', 'Lee, Frederick Richard')
# ('L', 'Lee, Seung-Taek')
# ('L', 'Lee, Sydney')
# ('L', 'Lee, Thomas Stirling')
# ('L', 'Lee, Ufan')
# ('L', 'Leech, John')
# ('L', 'Lees, Derwent')
# ('L', 'Legnaghi, Igino')
# ('L', 'Legros, Alphonse')
# ('L', 'Lehmbruck, Wilhelm')
# ('L', 'Leigh, Maude Boughton')
# ('L', 'Leighton, Lord Frederic')
# ('L', 'Leirner, Felicia')
# ('L', 'Leirner, Nelson')
# ('L', 'Lely, Sir Peter')
# ('L', 'Lemon, Arthur')
# ('L', 'Lenk, Kaspar-Thomas')
# ('L', 'Lennox, Lord William Pitt')
# ('L', 'Leonard, Zoe')
# ('L', 'Leonilson (José Leonilson Bezerra Dias)')
# ('L', 'Leslie, Alexander J.')
# ('L', 'Leslie, Charles Robert')
# ('L', 'Leslie, George Dunlop')
# ('L', 'Lessore, Helen')
# ('L', 'Lethaby, William Richard')
# ('L', 'Lethbridge, Julian')
# ('L', 'Lett-Haines, Arthur')
# ('L', 'Leung, Yau')
# ('L', 'Leverett, David')
# ('L', 'Levine, Sherrie')
# ('L', 'Levy, Simon')
# ('L', 'Lewis, A. Neville')
# ('L', 'Lewis, George Robert')
# ('L', 'Lewis, John Frederick')
# ('L', 'Lewis, Morland')
# ('L', 'Lewis, Wyndham')
# ('L', 'Lhote, André')
# ('L', 'Li, Yuan-chia')
# ('L', 'Libera, Zbigniew')
# ('L', 'Liberman, Alexander')
# ('L', 'Lichtenstein, Roy')
# ('L', 'Lieber, Tom')
# ...
# ('S', 'Shrigley, David')
# ('S', 'Siberechts, Jan')
# ('S', 'Sichel, Ernest Leopold')
# ('S', 'Sickert, Bernard')
# ('S', 'Sickert, Walter Richard')
# ('S', 'Siddal, Elizabeth Eleanor')
# ('S', 'Sierra, Santiago')
# ('S', 'Sietsema, Paul')
# ('S', 'Sillman, Amy')
# ('S', 'Simmonds, William G.')
# ('S', 'Simmons, Laurie')
# ('S', 'Simmons, Rosemary')
# ('S', 'Simon, Taryn')
# ('S', 'Simpson, Jane')
# ('S', 'Simpson, John')
# ('S', 'Simpson, Lorna')
# ('S', 'Sims, Charles')
# ('S', 'Singier, Gustave')
# ('S', 'Singleton, Henry')
# ('S', 'Sintenis, Renée')
# ('S', 'Sironi, Mario')
# ('S', 'Siskind, Aaron')
# ('S', 'Sisley, Alfred')
# ('S', 'Skaer, Lucy')
# ('S', 'Skeaf, D.')
# ('S', 'Skeaping, John')
# ('S', 'Skelton, Jonathan')
# ('S', 'Skippe, John')
# ('S', 'Skiöld, Birgit')
# ('S', 'Slaughter, Stephen')
# ('S', 'Slawik, Bernard')
# ('S', 'Sleap, Joseph Axe')
# ('S', 'Sleter, Francesco')
# ('S', 'Slominski, Andreas')
# ('S', 'Small, William')
# ('S', 'Smallwood, William Frome')
# ('S', 'Smart, Edgar Rowley')
# ('S', 'Smetham, James')
# ('S', 'Smirke, Robert')
# ('S', 'Smith, Bob and Roberta')
# ('S', 'Smith, Colin')
# ('S', 'Smith, David')
# ('S', 'Smith, Frederick William')
# ('S', 'Smith, George, of Chichester')
# ('S', 'Smith, Gordon')
# ('S', 'Smith, Hassel')
# ('S', 'Smith, Jack')
# ('S', 'Smith, Joel')
# ('S', 'Smith, John')
# ('S', 'Smith, John Raphael')
# ('S', 'Smith, John Thomas')
# ('S', "Smith, John `Warwick'")
# ('S', 'Smith, Joseph Clarendon')
# ('S', 'Smith, Keir')
# ('S', 'Smith, Kiki')
# ('S', 'Smith, Melanie')
# ('S', 'Smith, Richard')
# ('S', 'Smith, Sidney Robert James')
# ('S', 'Smith, Sir Matthew')
# ('S', 'Smith, Stephanie')
# ('S', 'Smith, Thomas')
# ('S', 'Smith, W. Eugene')
# ('S', 'Smithson, Robert')
# ('S', 'Smythe, Lionel Percy')
# ('S', 'Soares, Valeska')
# ('S', 'Sobrino, Francisco')
# ('S', 'Soest, Gilbert')
# ('S', 'Solakov, Nedko')
# ('S', 'Soldi, Andrea')
# ('S', 'Solien, T.L.')
# ('S', 'Solomon, Abraham')
# ('S', 'Solomon, Simeon')
# ('S', 'Solomon, Solomon J.')
# ('S', 'Somerscales, Thomas J.')
# ('S', 'Somov, Konstantin')
# ('S', 'Sone, Yutaka')
# ('S', 'Sonnier, Keith')
# ('S', 'Sorel, Agathe')
# ('S', 'Sorman, Steven')
# ('S', 'Sorrell, Alan')
# ('S', 'Sorrell, Elizabeth')
# ('S', 'Soto, Jesus Rafael')
# ('S', 'Souch, John')
# ('S', 'Soukop, Willi')
# ('S', 'Soulages, Pierre')
# ('S', 'Southall, Derek')
# ('S', 'Southall, Joseph Edward')
# ('S', 'Soutine, Chaïm')
# ('S', 'Souza, F.N.')
# ('S', 'Spear, Ruskin')
# ('S', 'Speed, Harold')
# ('S', 'Spencelayh, Charles')
# ('S', 'Spencer Watson, George')
# ('S', 'Spencer, Gilbert')
# ('S', 'Spencer, Jean')
# ('S', 'Spencer, Lady')
# ('S', 'Spencer, Sir Stanley')
# ('S', 'Spencer, Thomas')
# ('S', 'Spender, John Humphrey')
# ('S', 'Spero, Nancy')
# ('S', 'Spilsbury, Maria')
# ('S', 'Spoerri, Daniel')
# ('S', 'Spruance, Benton')
# ('S', 'Spurrier, Steven')
# ('S', 'St John Long, John St John')
# ('S', 'Stael, Nicolas de')
# ('S', 'Stahly, François')
# ('S', 'Stamos, Theodorus')
# ('S', 'Stanfield, Clarkson Frederick')
# ('S', 'Stanhope, John Roddam Spencer')
# ('S', 'Stanley, Lady Dorothy')
# ('S', 'Starczewski, Antoni')
# ('S', 'Stark, James')
# ('S', 'Stark, Robert')
# ('S', 'Starkey, Hannah')
# ('S', 'Starling, Simon')
# ('S', 'Starr, Georgina')
# ('S', 'Starr, Sydney')
# ('S', 'Startup, Peter')
# ('S', 'Staton, Sarah')
# ('S', 'Stazewski, Henryk')
# ('S', 'Steadman, Ralph')
# ('S', 'Steele, Jeffrey')
# ('S', 'Steer, Philip Wilson')
# ('S', 'Stein, Ronald')
# ('S', 'Steinlen, Théophile-Alexandre')
# ('S', 'Steir, Pat')
# ('S', 'Stella, Frank')
# ('S', 'Stephens, Frederic George')
# ('S', 'Stephenson, Ian')
# ('S', 'Stephenson, John Cecil')
# ('S', 'Stern, Grete')
# ('S', 'Sterne, Hedda')
# ('S', 'Sterne, Maurice')
# ('S', 'Stevens, Alfred')
# ('S', 'Stevens, Norman')
# ('S', 'Stevenson, James')
# ('S', 'Stevenson, Robert Alan Mowbray')
# ('S', 'Stezaker, John')
# ('S', 'Still, Clyfford')
# ('S', 'Stokes, Adrian')
# ('S', 'Stokes, Marianne')
# ('S', 'Stone, Marcus')
# ('S', 'Storey, George Adolphus')
# ('S', 'Stothard, Thomas')
# ('S', 'Stott of Oldham, William')
# ('S', 'Stott, Edward')
# ('S', 'Strang, Ian')
# ('S', 'Strang, William')
# ('S', 'Streatfeild, Robert')
# ('S', 'Stringer, Daniel')
# ('S', 'Stroud, Peter')
# ('S', 'Strudwick, John Melhuish')
# ('S', 'Strunke, Niklavs')
# ('S', 'Struth, Thomas')
# ('S', 'Strutt, Arthur John')
# ('S', 'Stuart, Gilbert')
# ('S', 'Stubbing, N.H.')
# ('S', 'Stubbs, George')
# ('S', 'Studd, Arthur')
# ('S', 'Studin, Marin')
# ('S', 'Suga, Kishio')
# ('S', 'Sugimoto, Hiroshi')
# ('S', 'Suh, Do Ho')
# ('S', 'Sullivan, Catherine')
# ('S', 'Sullivan, Christine')
# ('S', 'Sullivan, Edmund J.')
# ('S', 'Sultan, Altoon')
# ('S', 'Sultan, Donald')
# ('S', 'Sultan, Larry')
# ('S', 'Summers, Carol')
# ('S', 'Sunderland, Thomas')
# ('S', 'Suschitzky, Peter')
# ('S', 'Sutej, Miroslav')
# ('S', 'Sutherland, Elizabeth Leveson-Gower, Duchess-Countess of')
# ('S', 'Sutherland, Graham, OM')
# ('S', 'Sutton, Philip')
# ('S', 'Sutton, Trevor')
# ('S', 'Swain, Tony')
# ('S', 'Swan, John Macallan')
# ('S', 'Swanson, John')
# ('S', 'Swoon')
# ('S', 'Swynnerton, Annie Louisa')
# ('S', 'Sydney, Berenice')
# ('S', 'Symons, Patrick')
# ('S', 'Szapocznikow, Alina')
# ('T', 'T R Uthco (Doug Hall born 1944, Diane Andrews Hall born 1945, Jody Procter 1944-1998)')
# ('T', 'Takahashi, Tomoko')
# ('T', 'Takamatsu, Jiro')
# ('T', 'Takis')
# ('T', 'Talmage, Algernon')
# ('T', 'Tamayo, Rufino')
# ('T', 'Tan, Fiona')
# ('T', 'Tanabe, Takao')
# ('T', 'Tanavoli, Parviz')
# ('T', 'Tanguy, Yves')
# ('T', 'Tanning, Dorothea')
# ('T', 'Tapies, Antoni')
# ('T', 'Taslitzky, Boris')
# ('T', 'Tassaert, Philippe Joseph')
# ('T', 'Taverner, William')
# ('T', 'Tayler, Frederick')
# ('T', 'Taylor, John, of Bath')
# ('T', 'Taylor, Leonard Campbell')
# ('T', 'Taylor, Marcus')
# ('T', 'Taylor, Richard')
# ('T', 'Taylor, Walter')
# ('T', 'Taylor-Johnson, OBE Sam')
# ('T', 'Tchelitchew, Pavel')
# ('T', 'Tenniel, Sir John')
# ('T', 'Teraoka, Masami')
# ('T', 'Teshigahara, Sofu')
# ('T', 'Tharrats, Joan-Josep')
# ('T', 'The Leach Pottery (St. Ives, UK)')
# ('T', 'Therrien, Robert')
# ('T', 'Thiebaud, Wayne')
# ('T', 'Thirsk, John')
# ('T', 'Thirtle, John')
# ('T', 'Thomas, George Havard')
# ('T', 'Thomas, George Housman')
# ('T', 'Thomas, James Havard')
# ('T', 'Thomas, John')
# ('T', 'Thomkins, André')
# ('T', 'Thompson, Jon')
# ('T', 'Thomson, Alfred R.')
# ('T', 'Thomson, George')
# ('T', 'Thomson, Henry')
# ('T', 'Thomson, Rev. John, of Duddingston')
# ('T', 'Thomson, W.')
# ('T', 'Thornhill, Sir James')
# ('T', 'Thornton, Alfred')
# ('T', 'Thornton, Valerie')
# ('T', 'Thornycroft, Sir Hamo')
# ('T', 'Thrall, Arthur')
# ('T', 'Thubron, Harry')
# ('T', 'Thuring, Caragh')
# ('T', 'Tibble, Geoffrey')
# ('T', 'Tickle, Matthew')
# ('T', 'Tillemans, Peter')
# ('T', 'Tillim, Guy')
# ('T', 'Tillmans, Wolfgang')
# ('T', 'Tillyer, William')
# ('T', 'Tilson, Jake')
# ('T', 'Tilson, Joe')
# ('T', 'Tindle, David')
# ('T', 'Ting, Walasse')
# ('T', 'Tinguely, Jean')
# ('T', 'Tiravanija, Rirkrit')
# ('T', 'Tisdall, Hans')
# ('T', 'Tissot, James')
# ('T', 'Titchner, Mark')
# ('T', 'Tobey, Mark')
# ('T', 'Todd, A.R. Middleton')
# ('T', 'Toft, Albert')
# ('T', 'Toledano, Edward')
# ('T', 'Tollemache')
# ('T', 'Tomkins, William')
# ('T', 'Tomlin, Stephen')
# ('T', 'Tompkins, Hayley')
# ('T', 'Tonks, Henry')
# ('T', 'Topolski, Feliks')
# ('T', 'Toren, Amikam')
# ('T', 'Torner, Gustavo')
# ('T', 'Toulouse-Lautrec, Henri de')
# ('T', 'Tousignant, Serge')
# ('T', 'Town, Harold')
# ('T', 'Towne, Francis')
# ('T', 'Townroe, Reuben')
# ('T', 'Townsend, William')
# ('T', 'Travis, Ann')
# ('T', 'Treister, Suzanne')
# ('T', 'Tremblay, Gerard')
# ('T', 'Tremlett, David')
# ('T', 'Tresham, Henry')
# ('T', 'Trevelyan, Julian')
# ('T', 'Trockel, Rosemarie')
# ('T', 'Troostwyk, David')
# ('T', 'Troubetzkoy, Paul')
# ('T', 'Trova, Ernest')
# ('T', 'Trower, Walter John, Bishop of Gibraltar')
# ('T', 'Tryon, Wyndham')
# ('T', 'Tsai, Wen-Ying')
# ('T', 'Tsapline, Dmitri')
# ('T', 'Tucker, William')
# ('T', 'Tudor, Thomas')
# ('T', 'Tuke, Henry Scott')
# ('T', 'Tunnard, John')
# ('T', 'Turk, Gavin')
# ('T', 'Turnbull, Alison')
# ('T', 'Turnbull, William')
# ('T', 'Turner, Alfred')
# ('T', 'Turner, Bruce')
# ('T', 'Turner, Charles')
# ('T', 'Turner, Daniel')
# ('T', 'Turner, F.C.')
# ('T', 'Turner, Joseph Mallord William')
# ('T', 'Turner, W.')
# ('T', 'Turner, William, of Oxford')
# ('T', 'Turner, Winifred')
# ('T', 'Turton, M.')
# ('T', 'Tuttle, Richard')
# ('T', 'Tuymans, Luc')
# ('T', 'Tweed, John')
# ('T', 'Twombly, Cy')
# ('T', 'Tworkov, Jack')
# ('T', 'Tyrwhitt, Ursula')
# ('T', 'Tyson, Ian')
# ('T', 'Tyson, Keith')
# ('T', 'Tyson, Nicola')
# ('T', 'Tyzack, Michael')
# ('T', 'Téllez, Javier')
# ('U', 'Uecker, Gunther')
# ('U', 'Uglow, Euan')
# ('U', 'Uhlig, Max')
# ('U', 'Uklanski, Piotr')
# ('U', 'Ullman, Micha')
# ('U', 'Ulreich, Edward Buk')
# ('U', 'Underwood, Leon')
# ('U', 'Underwood, Thomas Richard')
# ('U', 'Unwin, Francis')
# ('U', 'Unwin, Marianne')
# ('U', 'Unwin, Phoebe')
# ('U', 'Upritchard, Francis')
# ('U', 'Uslé, Juan')
# ('U', 'Utrillo, Maurice')
# ('U', 'Uwins, Thomas')
# ('V', 'Vacher, Charles')
# ('V', 'Vale, João Pedro')
# ('V', 'Valenti, Italo')
# ('V', 'Vallotton, Félix')
# ('V', 'Valoch, Jiri')
# ('V', 'Van Aken, Joseph')
# ('V', 'Van Assen, Benedict Anthony')
# ('V', 'Van Der Zee, James')
# ('V', 'Van Dyck, Sir Anthony')
# ('V', 'Van Heemskerk, Egbert, III')
# ('V', 'Van Leyden, Ernst')
# ('V', 'Van Somer, Paul')
# ('V', 'Vanderbank, John')
# ('V', 'Vantongerloo, Georges')
# ('V', 'Vardea, Chryssa')
# ('V', 'Varley, Cornelius')
# ('V', 'Varley, John')
# ('V', 'Varley, William Fleetwood')
# ('V', 'Vasarely, Victor')
# ('V', 'Vaughan, Keith')
# ('V', 'Vaux, Marc')
# ('V', 'Vedova, Emilio')
# ('V', 'Velde, Bram van')
# ('V', 'Velickovic, Vladimir')
# ('V', 'Venard, Claude')
# ('V', 'Vercruysse, Jan')
# ('V', 'Verelst, Harman')
# ('V', 'Verheyen, Jeff')
# ('V', 'Verlon, André')
# ('V', 'Vermeiren, Didier')
# ('V', 'Verrio, Antonio')
# ('V', 'Vidokle, Anton')
# ('V', 'Vieira da Silva, Maria Helena')
# ('V', 'Vilaincour, Leon')
# ('V', 'Villard, Antoine')
# ('V', 'Villeglé, Jacques Mahé de la')
# ('V', 'Villers, Dee')
# ('V', 'Viola, Bill')
# ('V', 'Virtue, John')
# ('V', 'Visser, Carel')
# ('V', 'Vlahos, Vangelis')
# ('V', 'Vlaminck, Maurice de')
# ('V', 'Vollon, Antoine')
# ('V', 'Von Herkomer, Sir Hubert')
# ('V', 'Von Motesiczky, Marie-Louise')
# ('V', 'Vonna-Michell, Tris')
# ('V', 'Vordemberge-Gildewart, Friedrich')
# ('V', 'Vuillard, Edouard')
# ('V', 'Vuong, Ha van')
# ('V', 'Vézelay, Paule')
# ('W', 'Wade, Thomas')
# ('W', 'Wadsworth, Edward')
# ('W', 'Wainwright, John')
# ('W', 'Wale, Samuel')
# ('W', 'Walker, Anthony')
# ('W', 'Walker, Arthur G')
# ('W', 'Walker, Dame Ethel')
# ('W', 'Walker, Frederick')
# ('W', 'Walker, John')
# ('W', 'Walker, Kara')
# ('W', 'Walker, Kelley')
# ('W', 'Wall, Brian')
# ('W', 'Wall, Jeff')
# ('W', 'Waller, Samuel')
# ('W', 'Wallinger, Mark')
# ('W', 'Wallis, Alfred')
# ('W', 'Wallis, Henry')
# ('W', 'Walmsley, William')
# ('W', 'Walton, Edward Arthur')
# ('W', 'Walton, Henry')
# ('W', 'Ward, Edward Matthew')
# ('W', 'Ward, James')
# ('W', 'Ward, John')
# ('W', 'Wardill, Emily')
# ('W', 'Wardle, Arthur')
# ('W', 'Warhol, Andy')
# ('W', 'Warren, Michael')
# ('W', 'Warren, Rebecca')
# ('W', 'Waterford, Louisa Anne, Marchioness of')
# ('W', 'Waterhouse, John William')
# ('W', 'Waterlow, Sir Ernest Albert')
# ('W', 'Watson, Harry')
# ('W', 'Watson, John Dawson')
# ('W', 'Watson, Lyall')
# ('W', 'Watt, George Fiddes')
# ('W', 'Watts, Frederick Waters')
# ('W', 'Watts, George Frederic')
# ('W', 'Wearing, OBE Gillian')
# ('W', 'Weaver, Thomas')
# ('W', 'Webb, Boyd')
# ('W', 'Webb, Gary')
# ('W', 'Webb, James')
# ('W', 'Webb, Philip')
# ('W', 'Webster, Thomas')
# ('W', 'Wedemeyer, Clemens von')
# ('W', 'Weekes, Henry')
# ('W', 'Weerasethakul, Apichatpong')
# ('W', 'Wegner, Nicholas')
# ('W', 'Weight, Carel')
# ('W', 'Weiner, Lawrence')
# ('W', 'Welch, Denton')
# ('W', 'Wellington, Hubert L.')
# ('W', 'Wells, Henry Tanworth')
# ('W', 'Wells, Joanna Mary')
# ('W', 'Wells, John')
# ('W', 'Wemaere, Pierre')
# ('W', 'Wendt, Lionel')
# ('W', 'Wentworth, Richard')
# ('W', 'Wermers, Nicole')
# ('W', 'Weschke, Karl')
# ('W', 'Wesselmann, Tom')
# ('W', 'West, Benjamin')
# ('W', 'West, Franz')
# ('W', 'West, Walter')
# ('W', 'Westall, Richard')
# ('W', 'Westall, William')
# ('W', 'Weston, Edward')
# ('W', 'Wharncliffe, Lady')
# ('W', 'Wheatley, Clara')
# ('W', 'Wheatley, Francis')
# ('W', 'Wheatley, Grace')
# ('W', 'Wheatley, John')
# ('W', 'Wheeler, Sir Charles')
# ('W', 'Whishaw, Anthony')
# ('W', 'Whistler, James Abbott McNeill')
# ('W', 'Whistler, Rex')
# ('W', 'Whitcombe, Thomas')
# ('W', 'White, Ethelbert')
# ('W', 'White, Lt-Col George Francis')
# ('W', 'White, Pae')
# ('W', 'Whiteford, Kate')
# ('W', 'Whiteley, Brett')
# ('W', 'Whiteread, Rachel')
# ('W', 'Whitney-Smith, Edwin')
# ('W', 'Whitten, Jack')
# ('W', 'Wiener, Martin')
# ('W', 'Wiens, Stephen M.')
# ('W', 'Wigram, Max')
# ('W', 'Wilde, Gerald')
# ('W', 'Wilding, Alison')
# ('W', 'Wilke, Hannah')
# ('W', 'Wilkes, Cathy')
# ('W', 'Wilkie, Sir David')
# ('W', 'Willats, Stephen')
# ('W', 'Willcock, George Burrell')
# ('W', 'Williams, Aubrey')
# ('W', 'Williams, Christopher')
# ('W', 'Williams, Edward')
# ('W', 'Williams, Fred')
# ('W', 'Williams, Glynn')
# ('W', 'Williams, Hugh William')
# ('W', 'Williams, Kyffin')
# ('W', 'Williams, Penry')
# ('W', 'Williams, Terrick')
# ('W', 'Williams, William')
# ('W', 'Willing, Victor')
# ('W', 'Willson, Terry')
# ('W', 'Wilson, Andrew')
# ('W', 'Wilson, Fred')
# ('W', 'Wilson, Jane')
# ('W', 'Wilson, Louise')
# ('W', 'Wilson, Richard')
# ('W', 'Wilson, Scottie')
# ('W', 'Wilson, William A.')
# ('W', 'Windus, William Lindsay')
# ('W', 'Wines, James')
# ('W', 'Winner, Gerd')
# ('W', 'Winstanley, Paul')
# ('W', 'Winters, Terry')
# ('W', 'Wintour, John Crawford')
# ('W', 'Wise, Gillian')
# ('W', 'Wiseman, Albany')
# ('W', 'Wissing, Willem')
# ('W', 'Wiszniewski, Adrian')
# ('W', 'Witherington, William Frederick')
# ('W', 'Witkin, Isaac')
# ('W', 'Wojnarowicz, David')
# ('W', 'Wolfe, Edward')
# ('W', 'Wolfe, Robert')
# ('W', 'Wolff, Christian')
# ('W', 'Wolff, Robert Jay')
# ('W', 'Wolmark, Alfred')
# ('W', 'Wols')
# ('W', 'Wong, Judy')
# ('W', 'Wonnacott, John')
# ('W', 'Wood, Christopher')
# ('W', 'Wood, Craig')
# ('W', 'Wood, F. Derwent')
# ('W', 'Woodforde, Samuel')
# ('W', 'Woodham, Derrick')
# ('W', 'Woodman, Francesca')
# ('W', 'Woodrow, Bill')
# ('W', 'Woods, Henry')
# ('W', 'Woodville, Richard Caton')
# ('W', 'Woodward, George Montard')
# ('W', 'Woodward, Thomas')
# ('W', 'Wool, Christopher')
# ('W', 'Woolner, Thomas')
# ('W', 'Wootton, John')
# ('W', 'Worlidge, Thomas')
# ('W', 'Wotruba, Fritz')
# ('W', 'Wragg, John')
# ('W', 'Wright, Austin')
# ('W', 'Wright, Edward')
# ('W', 'Wright, Elizabeth')
# ('W', 'Wright, John Michael')
# ('W', 'Wright, Joseph, of Derby')
# ('W', 'Wright, Richard')
# ('W', 'Wunderlich, Paul')
# ('W', 'Wyatt, Henry')
# ('W', 'Wyck, Jan')
# ('W', 'Wyckaert, Maurice')
# ('W', 'Wykeham Archer, J.')
# ('W', 'Wylie, Rose')
# ('W', 'Wyllie, Charles William')
# ('W', 'Wyllie, William Lionel')
# ('W', 'Wyn Evans, Cerith')
# ('W', 'Wynne, David')
# ('W', 'Wynter, Bryan')
# ('X', 'Xu, Zhen')
# ('Y', 'Yagaki, Shikanosuke')
# ('Y', 'Yale, Brian')
# ('Y', 'Yalter, Nil')
# ('Y', 'Yamaguchi, Katsuhiro')
# ('Y', 'Yamawaki, Iwao')
# ('Y', 'Yanagi, Yukinori')
# ('Y', 'Yang, Fudong')
# ('Y', 'Yarrow, Catherine')
# ('Y', 'Yass, Catherine')
# ('Y', 'Yeames, William Frederick')
# ('Y', 'Yeats, Jack Butler')
# ('Y', 'Yhap, Laetitia')
# ('Y', 'Yiadom-Boakye, Lynette')
# ('Y', 'Young, Carey')
# ('Y', 'Young, Robert')
# ('Y', 'Young-Hae Chang Heavy Industries (Young-Hae Chang, Marc Voge)')
# ('Y', 'Young-Hunter, John')
# ('Y', 'Yuon, Konstantin')
# ('Y', 'Yvaral, Jean-Pierre')
# ('Z', 'Zaatari, Akram')
# ('Z', 'Zack, Leon')
# ('Z', 'Zadkine, Ossip')
# ('Z', 'Zakanitch, Robert Rahway')
# ('Z', 'Zao, Wou-ki')
# ('Z', 'Zhang, Enli')
# ('Z', 'Ziegler, Toby')
# ('Z', 'Zipp, Thomas')
# ('Z', 'Zittel, Andrea')
# ('Z', 'Zmijewski, Artur')
# ('Z', 'Zoffany, Johan')
# ('Z', 'Zorio, Gilberto')
# ('Z', 'Zox, Larry')
# ('Z', 'Zuccarelli, Francesco')
# ('Z', 'Zuloaga, Ignacio')
# ('Z', 'Zyw, Aleksander')
# ('d', 'di Suvero, Mark')
# ('v', 'van Elk, Ger')
# ('Š', 'Štyrský, Jindrich')
# distinct artist count: 3336
# # of works by Bacon, Francis is: 50
# columns:  Index(['WorkCount'], dtype='object')
#
# columns: Index(['WorkCount'], dtype='object')
#                                 WorkCount
# Turner, Joseph Mallord William      39389
# Jones, George                        1046
# Moore, Henry, OM, CH                  623
# Daniell, William                      612
# Beuys, Joseph                         578
# ...                                   ...
# Van Somer, Paul                         1
# Herold, Georg                           1
# Porter, Frederick J.                    1
# Cross, Dorothy                          1
# Smith, Thomas                           1
#
# [3336 rows x 1 columns]

# %%
df = retrieve_from_pickle("save_file")
df.rename(columns={"title": "Long Title"}, inplace=True)

# %%
df[1:10][['Long Title', "artist", "medium", ]]
# Out:
#                                              Long Title          artist  \
# id
# 1036  Two Drawings of Frightened Figures, Probably f...   Blake, Robert
# 1037  The Preaching of Warning. Verso: An Old Man En...   Blake, Robert
# 1038     Six Drawings of Figures with Outstretched Arms   Blake, Robert
# 1039  The Circle of the Lustful: Francesca da Rimini...  Blake, William
# 1040      Ciampolo the Barrator Tormented by the Devils  Blake, William
# 1041                        The Baffled Devils Fighting  Blake, William
# 1042  The Six-Footed Serpent Attacking Agnolo Brunel...  Blake, William
# 1043                 The Serpent Attacking Buoso Donati  Blake, William
# 1044                 The Pit of Disease: The Falsifiers  Blake, William
#
#                                            medium
# id
# 1036                            Graphite on paper
# 1037  Graphite on paper. Verso: graphite on paper
# 1038                            Graphite on paper
# 1039                      Line engraving on paper
# 1040                      Line engraving on paper
# 1041                      Line engraving on paper
# 1042                      Line engraving on paper
# 1043                      Line engraving on paper
# 1044                      Line engraving on paper

# %%
df[1:10][['Long Title', "artist", "medium", ]].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-3b74fd3b6ef3> in <module>
# ----> 1 df[1:10][['Long Title', "artist", "medium", ]].value_count()
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_count'

# %%
df = df[1:10][['Long Title', "artist", "medium", ]]

# %%
df = df["artist"].value_counts()

# %%
df
# Out:
# Blake, William    6
# Blake, Robert     3
# Name: artist, dtype: int64

# %%
df = DataFrame(data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-cac97538ec67> in <module>
# ----> 1 df = DataFrame(data=df)
#
# NameError: name 'DataFrame' is not defined

# %%
df = pd.DataFrame(data=df)

# %%
df
# Out:
#                 artist
# Blake, William       6
# Blake, Robert        3

# %%
df.rename(columns={'artist':'count'}, inplace=True)

# %%
df
# Out:
#                 count
# Blake, William      6
# Blake, Robert       3

# %%
df['artist']=df.index

# %%
df
# Out:
#                 count          artist
# Blake, William      6  Blake, William
# Blake, Robert       3   Blake, Robert

# %%
df[['artist', 'count']].print(index=false)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-116b1807e22d> in <module>
# ----> 1 df[['artist', 'count']].print(index=false)
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'print'

# %%
df.reset_index()
# Out:
#             index  count          artist
# 0  Blake, William      6  Blake, William
# 1   Blake, Robert      3   Blake, Robert

# %%
df.index=''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-1adbb7ad2f3a> in <module>
# ----> 1 df.index=''
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     174
#     175     def set_axis(self, axis, new_labels):
# --> 176         new_labels = ensure_index(new_labels)
#     177         old_len = len(self.axes[axis])
#     178         new_len = len(new_labels)
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5769             index_like = copy(index_like)
#    5770
# -> 5771     return Index(index_like)
#    5772
#    5773
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     517             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#     518         elif data is None or is_scalar(data):
# --> 519             cls._scalar_data_error(data)
#     520         else:
#     521             if tupleize_cols and is_list_like(data):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/indexes/base.py in _scalar_data_error(cls, data)
#    4106         raise TypeError(
#    4107             "{0}(...) must be called with a collection of some "
# -> 4108             "kind, {1} was passed".format(cls.__name__, repr(data))
#    4109         )
#    4110
#
# TypeError: Index(...) must be called with a collection of some kind, '' was passed

# %%
df.index
# Out:
# Index(['Blake, William', 'Blake, Robert'], dtype='object')

# %%
df.rest_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-d14188afb001> in <module>
# ----> 1 df.rest_index()
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rest_index'

# %%
df.reset_index()
# Out:
#             index  count          artist
# 0  Blake, William      6  Blake, William
# 1   Blake, Robert      3   Blake, Robert

# %%
df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_407cba88_42db_11ea_a1f2_8c85906751af" ><thead>    <tr>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_407cba88_42db_11ea_a1f2_8c85906751afrow0_col0" class="data row0 col0" >6</td>
#                         <td id="T_407cba88_42db_11ea_a1f2_8c85906751afrow0_col1" class="data row0 col1" >Blake, William</td>
#             </tr>
#             <tr>
#                                 <td id="T_407cba88_42db_11ea_a1f2_8c85906751afrow1_col0" class="data row1 col0" >3</td>
#                         <td id="T_407cba88_42db_11ea_a1f2_8c85906751afrow1_col1" class="data row1 col1" >Blake, Robert</td>
#             </tr>
#     </tbody></table>

# %%
df
# Out:
#                 count          artist
# Blake, William      6  Blake, William
# Blake, Robert       3   Blake, Robert

# %%
df[['artist', 'count']]
# Out:
#                         artist  count
# Blake, William  Blake, William      6
# Blake, Robert    Blake, Robert      3

# %%
df[['artist', 'count']].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_759080a6_42db_11ea_a1f2_8c85906751af" ><thead>    <tr>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_759080a6_42db_11ea_a1f2_8c85906751afrow0_col0" class="data row0 col0" >Blake, William</td>
#                         <td id="T_759080a6_42db_11ea_a1f2_8c85906751afrow0_col1" class="data row0 col1" >6</td>
#             </tr>
#             <tr>
#                                 <td id="T_759080a6_42db_11ea_a1f2_8c85906751afrow1_col0" class="data row1 col0" >Blake, Robert</td>
#                         <td id="T_759080a6_42db_11ea_a1f2_8c85906751afrow1_col1" class="data row1 col1" >3</td>
#             </tr>
#     </tbody></table>

# %%
df
# Out:
#                 count          artist
# Blake, William      6  Blake, William
# Blake, Robert       3   Blake, Robert

# %%
df.reset_index()
# Out:
#             index  count          artist
# 0  Blake, William      6  Blake, William
# 1   Blake, Robert      3   Blake, Robert

# %%
df.style.columns?

# %%
df.plot()
